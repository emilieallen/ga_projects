# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 1
#
# ### Building "Pokemon Stay"
#
# ---
# You are an analyst at a "scrappy" online gaming company that specializes in remakes of last year's fads.
#
# Your boss, who runs the product development team, is convinced that Pokemon Go's fatal flaw was that you had to actually move around outside. She has design mock-ups for a new game called Pokemon Stay: in this version players still need to move, but just from website to website. Pokemon gyms are now popular online destinations, and catching Pokemon in the "wild" simply requires browsing the internet for hours in the comfort of your home.
#
# She wants you to program a prototype version of the game and analyze the planned content to help the team calibrate the design.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Building-&quot;Pokemon-Stay&quot;" data-toc-modified-id="Building-&quot;Pokemon-Stay&quot;-0.1">Building "Pokemon Stay"</a></span><ul class="toc-item"><li><span><a href="#Package-imports" data-toc-modified-id="Package-imports-0.1.1">Package imports</a></span></li></ul></li></ul></li><li><span><a href="#1.-Defining-a-player" data-toc-modified-id="1.-Defining-a-player-1">1. Defining a player</a></span></li><li><span><a href="#2.-Defining-&quot;gym&quot;-locations" data-toc-modified-id="2.-Defining-&quot;gym&quot;-locations-2">2. Defining "gym" locations</a></span></li><li><span><a href="#3.-Create-a-pokedex" data-toc-modified-id="3.-Create-a-pokedex-3">3. Create a pokedex</a></span></li><li><span><a href="#4.-Create-a-data-structure-for-players" data-toc-modified-id="4.-Create-a-data-structure-for-players-4">4. Create a data structure for players</a></span><ul class="toc-item"><li><span><a href="#4.1" data-toc-modified-id="4.1-4.1">4.1</a></span></li><li><span><a href="#4.2" data-toc-modified-id="4.2-4.2">4.2</a></span></li></ul></li><li><span><a href="#5.-Add-captured-pokemon-for-each-player" data-toc-modified-id="5.-Add-captured-pokemon-for-each-player-5">5. Add captured pokemon for each player</a></span></li><li><span><a href="#6.-What-gyms-have-players-visited?" data-toc-modified-id="6.-What-gyms-have-players-visited?-6">6. What gyms have players visited?</a></span><ul class="toc-item"><li><span><a href="#6.1" data-toc-modified-id="6.1-6.1">6.1</a></span></li><li><span><a href="#6.2" data-toc-modified-id="6.2-6.2">6.2</a></span></li></ul></li><li><span><a href="#7.-Calculate-player-&quot;power&quot;." data-toc-modified-id="7.-Calculate-player-&quot;power&quot;.-7">7. Calculate player "power".</a></span></li><li><span><a href="#8.-Load-a-pokedex-file-containing-all-the-pokemon" data-toc-modified-id="8.-Load-a-pokedex-file-containing-all-the-pokemon-8">8. Load a pokedex file containing all the pokemon</a></span><ul class="toc-item"><li><span><a href="#8.1" data-toc-modified-id="8.1-8.1">8.1</a></span></li><li><span><a href="#8.2-Parse-the-raw-pokedex-with-list-comprehensions" data-toc-modified-id="8.2-Parse-the-raw-pokedex-with-list-comprehensions-8.2">8.2 Parse the raw pokedex with list comprehensions</a></span></li></ul></li><li><span><a href="#9.-Write-a-function-to-generate-the-full-pokedex" data-toc-modified-id="9.-Write-a-function-to-generate-the-full-pokedex-9">9. Write a function to generate the full pokedex</a></span></li><li><span><a href="#10.-Write-a-function-to-generate-a-&quot;filtered&quot;-pokedex" data-toc-modified-id="10.-Write-a-function-to-generate-a-&quot;filtered&quot;-pokedex-10">10. Write a function to generate a "filtered" pokedex</a></span></li><li><span><a href="#11.-Descriptive-statistics-on-the-prototype-pokedex" data-toc-modified-id="11.-Descriptive-statistics-on-the-prototype-pokedex-11">11. Descriptive statistics on the prototype pokedex</a></span><ul class="toc-item"><li><span><a href="#11.1" data-toc-modified-id="11.1-11.1">11.1</a></span></li><li><span><a href="#11.2" data-toc-modified-id="11.2-11.2">11.2</a></span></li></ul></li><li><span><a href="#12.-Calibrate-the-frequency-of-Pokemon" data-toc-modified-id="12.-Calibrate-the-frequency-of-Pokemon-12">12. Calibrate the frequency of Pokemon</a></span></li></ul></div>

# %% [markdown]
# #### Package imports
#
# The pprint package below is the only package imported here, and it's not even strictly required to do any of the project. Printing python variables and objects with pprint can help to format them in a "prettier" way.

# %%
from pprint import pprint

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Defining a player
#
# ---
#
# The player variables are:
#
#     player_id : id code unique to each player (integer)
#     player_name : entered name of the player (string)
#     time_played : number of times played the game in minutes (float)
#     player_pokemon: the player's captured pokemon (dictionary)
#     gyms_visited: ids of the gyms that a player has visited (list)
#
# Create the components for a player object by defining each of these variables. The dictionary and list variables should just be defined as empty; you can use any (correctly typed) values for the others.

# %%
# Defning variables

player_id = 1
player_name = 'Emilie'
time_played = float(15)
player_pokemon = {}
gyms_visited = []

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Defining "gym" locations
#
# ---
#
# As the sole programmer, Pokemon Stay will have to start small. To begin, there will be 10 different gym location websites on the internet. The gym locations are:
#
#     1. 'reddit.com'
#     2. 'amazon.com'
#     3. 'twitter.com'
#     4. 'linkedin.com'
#     5. 'ebay.com'
#     6. 'netflix.com'
#     7. 'sporcle.com'
#     8. 'stackoverflow.com'
#     9. 'github.com'
#     10. 'quora.com'
#
# 1. Set up a list of all the gym locations. This will be a list of strings.
# 2. Append two of these locations to your player's list of visited gyms.
# 3. Print the list.

# %%
# Creating a list of gym locations and gyms visited

gym_locations = ['reddit.com','amazon.com','twitter.com','linkedin.com','ebay.com','netflix.com',
                 'sporcle.com','stackoverflow.com','github.com','quora.com']

# %%
gyms_visited = [gym_locations[2], gym_locations[6]]

gyms_visited
# Out:
# ['twitter.com', 'sporcle.com']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Create a pokedex
#
# ---
#
# We also need to create some pokemon to catch. Each pokemon will be defined by these variables:
#
#     pokemon_id : unique identifier for each pokemon (integer)
#     name : the name of the pokemon (string)
#     type : the category of pokemon (string)
#     hp : base hitpoints (integer)
#     attack : base attack (integer)
#     defense : base defense (integer)
#     special_attack : base special attack (integer)
#     special_defense : base sepecial defense (integer)
#     speed : base speed (integer)
#
# We are only going to create 3 different pokemon with these `pokemon_id` and `pokemon_name` values:
#
#     1 : 'charmander'
#     2 : 'squirtle'
#     3 : 'bulbasaur'
#
# Create a dictionary that will contain the pokemon. The keys of the dictionary will be the `pokemon_id` and the values will themselves be dictionaries that contain the other pokemon variables. The structure of the pokedex dictionary will start like so:
#
#      {
#          1: {
#                  'name':'charmander',
#                  'type':'fire',
#                  ...
#
# The `type` of charmander, squirtle, and bulbasaur should be `'fire'`, `'water'`, and `'poison'` respectively. The other values are up to you, make them anything you like!
#
# Print (or pretty print) the pokedex dictionary with the 3 pokemon.

# %%
# Creating additional variables 
pokemon_id =[1,2,3]
pkmon_type =['fire','water','poison']
pkmon_name=['charmander','squirtle','bulbasaur']

# %%
# Creating a dictionary with the attributes of each pokemon_id

pokedex={1:{'name':'charmender',
            'type':'fire',
            'hp':2,
            'attack':6,
            'defense':8,
            'special_attack':6,
            'special_defense':4,
            'speed':6},
         
         2:{'name':'squirtle',
            'type':'water',
            'hp':3,
            'attack':5,
            'defense':9,
            'special_attack':4,
            'special_defense':5,
            'speed':7},
         
         3:{'name':'bulbasaur', 
            'type':'poison',
            'hp':4,
            'attack':7,
            'defense':7,
            'special_attack':8,
            'special_defense':2,
            'speed':5}}

pokedex
# Out:
# {1: {'name': 'charmender',
#   'type': 'fire',
#   'hp': 2,
#   'attack': 6,
#   'defense': 8,
#   'special_attack': 6,
#   'special_defense': 4,
#   'speed': 6},
#  2: {'name': 'squirtle',
#   'type': 'water',
#   'hp': 3,
#   'attack': 5,
#   'defense': 9,
#   'special_attack': 4,
#   'special_defense': 5,
#   'speed': 7},
#  3: {'name': 'bulbasaur',
#   'type': 'poison',
#   'hp': 4,
#   'attack': 7,
#   'defense': 7,
#   'special_attack': 8,
#   'special_defense': 2,
#   'speed': 5}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Create a data structure for players
#
# ---
#
# ### 4.1
#
# In order to maintain a database of multiple players, create a dictionary that keeps track of players indexed by `player_id`.
#
# The keys of the dictionary will be `player_id` and the values will be dictionaries containing each player's variables (from question 1).
#
# Construct the `players` dictionary and insert the player that you defined in question 1, then print `players`.

# %%
# Creating a dictionary for players_id and information contained in variables from question1

players={player_id:{'Player name': player_name,
                        'Time Played':time_played,
                           'Player Pokemon':player_pokemon,
                               'Gym visited':gyms_visited}}

players
# Out:
# {1: {'Player name': 'Emilie',
#   'Time Played': 15.0,
#   'Player Pokemon': {},
#   'Gym visited': ['twitter.com', 'sporcle.com']}}

# %% [markdown]
# ---
#
# ### 4.2
#
# Create a new player with `player_id = 2` in the `players` dictionary. Leave the `'player_pokemon'` dictionary empty. Append `'stackoverflow'` and `'github.com'` to the `'gyms_visited'` list for player 2.
#
# The `'player_name'` and `'time_played'` values are up to you, but must be a string and float, respectively.
#
# Remember, the player_id is the key for the player in the players dictionary.
#
# Print the `players` dictionary with the new player inserted.

# %%
# Adding player 2 to the players dictionary 

players[2]={'Player name': 'Claudia',
                        'Time Played':20,
                        'Player Pokemon':{},
                        'Gym visited':gyms_visited+['stackoverflow.com','github.com']}

players
# Out:
# {1: {'Player name': 'Emilie',
#   'Time Played': 15.0,
#   'Player Pokemon': {},
#   'Gym visited': ['twitter.com', 'sporcle.com']},
#  2: {'Player name': 'Claudia',
#   'Time Played': 20,
#   'Player Pokemon': {},
#   'Gym visited': ['twitter.com',
#    'sporcle.com',
#    'stackoverflow.com',
#    'github.com']}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Add captured pokemon for each player
#
# ---
#
# The `'player_pokemon'` keyed dictionaries for each player keep track of which of the pokemon each player has.
#
# The keys of the `'player_pokemon'` dictionaries are the pokemon ids that correspond to the ids in the `pokedex` dictionary you created earlier. The values are integers specifying the stats for the pokemon.
#
# Give player 1 a squirtle. Give player 2 a charmander and a bulbasaur.
#
# Print the players dictionary after adding the pokemon for each player.

# %%
# Assigning pokemons from the pokedex dictionary to each player  

players[1]['Player Pokemon'][2]= pokedex[2]
players[2]['Player Pokemon'][1]= pokedex[1]


players
# Out:
# {1: {'Player name': 'Emilie',
#   'Time Played': 15.0,
#   'Player Pokemon': {2: {'name': 'squirtle',
#     'type': 'water',
#     'hp': 3,
#     'attack': 5,
#     'defense': 9,
#     'special_attack': 4,
#     'special_defense': 5,
#     'speed': 7}},
#   'Gym visited': ['twitter.com', 'sporcle.com']},
#  2: {'Player name': 'Claudia',
#   'Time Played': 20,
#   'Player Pokemon': {1: {'name': 'charmender',
#     'type': 'fire',
#     'hp': 2,
#     'attack': 6,
#     'defense': 8,
#     'special_attack': 6,
#     'special_defense': 4,
#     'speed': 6}},
#   'Gym visited': ['twitter.com',
#    'sporcle.com',
#    'stackoverflow.com',
#    'github.com']}}

# %% [markdown]
# ## 6. What gyms have players visited?
#
# ---

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 6.1
#
# Write a for-loop that:
#
# 1. Iterates through the `pokemon_gyms` list of gym locations you defined before.
# 2. For each gym, iterate through each player in the `players` dictionary with a second, internal for-loop.
# 3. If the player has visited the gym, print out "[player] has visited [gym location].", filling in [player] and [gym location] with the current player's name and current gym location.

# %%
# Creating a loop to assess which gyms each player has visited from the gym_locations 
# Adding [n] to get the sum of n loops 

n=0
for i in gym_locations:
    for p in players:
        n=n+1
        if i in players[p]['Gym visited']:
            print(players[p]['Player name'],' has visited',i)
            
print('loop has run' )
n
# Out:
# Emilie  has visited twitter.com
# Claudia  has visited twitter.com
# Emilie  has visited sporcle.com
# Claudia  has visited sporcle.com
# Claudia  has visited stackoverflow.com
# Claudia  has visited github.com
# loop has run
# 20

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 6.2
#
# How many times did that loop run? If you have N gyms and also N players, how many times would it run as a function of N?
#
# Can you think of a more efficient way to accomplish the same thing?
#
# (You can write your answer as Markdown text.)

# %%
x = len(gym_locations)
y = len(players)

print('The loop ran',x*y)
# Out:
# The loop ran 20

# %% [markdown]
# N gymes and N players give N^2

# %% [markdown]
# To make it more efficient, we can start looping through the players and print the gyms each has visited. It removes 14 loops(from 20 to 6).

# %%
# looping through each player's gym_visited list and printing result
# adding n to count the number of loops

n=0
for p in players:
        for i in players[p]['Gym visited']:
            print(players[p]['Player name'],' has visited',i)
            n=n+1
n
# Out:
# Emilie  has visited twitter.com
# Emilie  has visited sporcle.com
# Claudia  has visited twitter.com
# Claudia  has visited sporcle.com
# Claudia  has visited stackoverflow.com
# Claudia  has visited github.com
# 6

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Calculate player "power".
#
# ---
#
# Define a function that will calculate a player's "power". Player power is defined as the sum of the base statistics of all their pokemon.
#
# Your function will:
#
# 1. Accept the `players` dictionary, `pokedex` dictionary, and a player_id as arguments.
# 2. For the specified player_id, look up that player's pokemon and their level(s).
# 3. Find and aggregate the attack and defense values for each of the player's pokemon from the `pokedex` dictionary.
# 4. Print "[player name]'s power is [player power].", where the player power is the sum of the base statistics for all of their pokemon.
# 5. Return the player's power value.
#
# Print out the pokemon power for each of your players.

# %%
# Creating function to assess player's power based on the attributes of the player_pokemon

def assess_power(players,pokedex,player_id):
    power = []
    
    for p in players[player_id]['Player Pokemon']:
        print(p)
        power.append(players[player_id]['Player Pokemon'][p]['attack'] 
                    + players[player_id]['Player Pokemon'][p]['defense'])
    
    power_value = sum(power)
    
    return(players[player_id]['Player name'] +"'s power is" + " " + str(power_value))

assess_power(players,pokedex,1)
# Out:
# 2
# "Emilie's power is 14"

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Load a pokedex file containing all the pokemon
#
# ---
#
# ### 8.1
#
# While you were putting together the prototype code, your colleagues were preparing a dataset of Pokemon and their attributes. (This was a rush job, so they may have picked some crazy values for some...)
#
# The code below loads information from a comma separated value (csv) file. You need to parse this string into a more useable format. The format of the string is:
#
# - Rows are separated by newline characters: \n
# - Columns are separated by commas: ,
# - All cells in the csv are double quoted. Ex: "PokedexNumber" is the first cell of the first row.
#
#
# Using for-loops, create a list of lists where each list within the overall list is a row of the csv/matrix, and each element in that list is a cell in that row. Additional criteria:
#
# 1. Quotes are removed from each cell item.
# 2. Numeric column values are converted to floats.
# 3. There are some cells that are empty and have no information. For these cells put a -1 value in place.
#
# Your end result is effectively a matrix. Each list in the outer list is a row, and the *j*th elements of the list together form the *j*th column, which represents a data attribute. The first three lists in your pokedex list should look like this:
#
#     ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#     [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#     [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %%
# Code to read in pokedex info
# the pokedex string is assigned to the raw_pd variable

raw_pd = ''
pokedex_file = 'pokedex_basic.csv'

with open(pokedex_file, 'r') as f:
    raw_pd = f.readlines()

# %%
# specified characters are replaced in lines

lines = []
for line in raw_pd:
    lines.append(line.replace('"', '').replace('\n', ''))
lines

# lines split after [,] and appended to new list data_split

data_split = []
for line in lines:
    data_split.append(line.split(','))

# row[0] separated from data_split and assigned to header

header = list(data_split[0])

# loop through lines in data_split replacing missing values with -1 and converting all numerical values to float
data_numeric = []

for line in data_split[1:]:
    new_line = []
    for i, col in enumerate(line):
        if i in [1, 2]:
            new_line.append(col)
        elif col == '':
            new_line.append(-1.0)
        else:
            new_line.append(float(col))
            
    data_numeric.append(new_line)

data_numeric.insert(0,header)

print(data_numeric[0])
print(data_numeric[1])
print(data_numeric[2])
# Out:
# ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
# [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
# [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Parse the raw pokedex with list comprehensions
#
# ---
#
# Perform the same parsing as above, but **using only a single list comprehension** instead of for loops. You may have nested list comprehensions within the main list comprehension! The output should be exactly the same.

# %%
# specified characters in lines replaced

lines = [line.replace('"','').replace('\n','') for line in raw_pd]

# %%
# split lines after commas 

y = [line.split(',') for line in lines]

# %%
# convert all numerical values to float, replace missing values with (-1) and print all lines in dataset

x = [y[0]]+[[col if i in [1,2] else -1.0 if col =='' else float(col) for i,col in enumerate(line)]
                     for line in y[1:]]
print(x[0])
print(x[1])
print(x[2])
# Out:
# ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
# [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
# [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Write a function to generate the full pokedex
#
# ---
#
# Write a function that recreates the pokedex you made before, but with the data read in from the full pokemon file. Create a unique key value for each entry in the pokemon dictionary.
#
# Your function should:
#
# 1. Take the parsed pokedex information you created above as an argument.
# 2. Return a dictionary in the same format as your original pokedex you created before containing the information from the parsed full pokedex file.
#
# To test the function, print out the pokemon with id = 100.

# %%
# set a list of pokemon_id looping through the pokemon file 

pokemon_id = [int(data_numeric[i][0]) for i in range(1,len(data_numeric))]

# overwrite pokedex dictionary with values from the pokemon file [data_numeric]
# assign each attribute's value to a variable 

pokedex = {k :{'name':data_numeric[k][1],
        'type':data_numeric[k][2],
        'hp':data_numeric[k][4],
        'attack':data_numeric[k][5],
        'defense':data_numeric[k][6],
        'special_attack':data_numeric[k][7],
        'special_defense':data_numeric[k][8],
        'speed':data_numeric[k][9],}for k in pokemon_id}

pokedex
# Out:
# {1: {'name': 'Bulbasaur',
#   'type': 'GrassPoison',
#   'hp': 45.0,
#   'attack': 49.0,
#   'defense': 49.0,
#   'special_attack': 65.0,
#   'special_defense': 65.0,
#   'speed': 45.0},
#  2: {'name': 'Ivysaur',
#   'type': 'GrassPoison',
#   'hp': 60.0,
#   'attack': 62.0,
#   'defense': 63.0,
#   'special_attack': 80.0,
#   'special_defense': 80.0,
#   'speed': 60.0},
#  3: {'name': 'Venusaur',
#   'type': 'GrassPoison',
#   'hp': 80.0,
#   'attack': 82.0,
#   'defense': 83.0,
#   'special_attack': 100.0,
#   'special_defense': 100.0,
#   'speed': 80.0},
#  4: {'name': 'VenusaurMega Venusaur',
#   'type': 'GrassPoison',
#   'hp': 80.0,
#   'attack': 100.0,
#   'defense': 123.0,
#   'special_attack': 122.0,
#   'special_defense': 120.0,
#   'speed': 80.0},
#  5: {'name': 'Charmander',
#   'type': 'Fire',
#   'hp': 39.0,
#   'attack': 52.0,
#   'defense': 43.0,
#   'special_attack': 60.0,
#   'special_defense': 50.0,
#   'speed': 65.0},
#  6: {'name': 'Charmeleon',
#   'type': 'Fire',
#   'hp': 58.0,
#   'attack': 64.0,
#   'defense': 58.0,
#   'special_attack': 80.0,
#   'special_defense': 65.0,
#   'speed': 80.0},
#  7: {'name': 'Charizard',
#   'type': 'FireFlying',
#   'hp': 78.0,
#   'attack': 84.0,
#   'defense': 78.0,
#   'special_attack': 109.0,
#   'special_defense': 85.0,
#   'speed': 100.0},
#  8: {'name': 'CharizardMega Charizard X',
#   'type': 'FireDragon',
#   'hp': 78.0,
#   'attack': 130.0,
#   'defense': 111.0,
#   'special_attack': 130.0,
#   'special_defense': 85.0,
#   'speed': 100.0},
#  9: {'name': 'CharizardMega Charizard Y',
#   'type': 'FireFlying',
#   'hp': 78.0,
#   'attack': 104.0,
#   'defense': 78.0,
#   'special_attack': 159.0,
#   'special_defense': 115.0,
#   'speed': 100.0},
#  10: {'name': 'Squirtle',
#   'type': 'Water',
#   'hp': 44.0,
#   'attack': 48.0,
#   'defense': 65.0,
#   'special_attack': 50.0,
#   'special_defense': 64.0,
#   'speed': 43.0},
#  11: {'name': 'Wartortle',
#   'type': 'Water',
#   'hp': 59.0,
#   'attack': 63.0,
#   'defense': 80.0,
#   'special_attack': 65.0,
#   'special_defense': 80.0,
#   'speed': 58.0},
#  12: {'name': 'Blastoise',
#   'type': 'Water',
#   'hp': 79.0,
#   'attack': 83.0,
#   'defense': 100.0,
#   'special_attack': 85.0,
#   'special_defense': 105.0,
#   'speed': 78.0},
#  13: {'name': 'BlastoiseMega Blastoise',
#   'type': 'Water',
#   'hp': 79.0,
#   'attack': 103.0,
#   'defense': 120.0,
#   'special_attack': 135.0,
#   'special_defense': 115.0,
#   'speed': 78.0},
#  14: {'name': 'Caterpie',
#   'type': 'Bug',
#   'hp': 45.0,
#   'attack': 30.0,
#   'defense': 35.0,
#   'special_attack': 20.0,
#   'special_defense': 20.0,
#   'speed': 45.0},
#  15: {'name': 'Metapod',
#   'type': 'Bug',
#   'hp': 50.0,
#   'attack': 20.0,
#   'defense': 55.0,
#   'special_attack': 25.0,
#   'special_defense': 25.0,
#   'speed': 30.0},
#  16: {'name': 'Butterfree',
#   'type': 'BugFlying',
#   'hp': 60.0,
#   'attack': 45.0,
#   'defense': 50.0,
#   'special_attack': 90.0,
#   'special_defense': 80.0,
#   'speed': 70.0},
#  17: {'name': 'Weedle',
#   'type': 'BugPoison',
#   'hp': 40.0,
#   'attack': 35.0,
#   'defense': 30.0,
#   'special_attack': 20.0,
#   'special_defense': 20.0,
#   'speed': 50.0},
#  18: {'name': 'Kakuna',
#   'type': 'BugPoison',
#   'hp': 45.0,
#   'attack': 25.0,
#   'defense': 50.0,
#   'special_attack': 25.0,
#   'special_defense': 25.0,
#   'speed': 35.0},
#  19: {'name': 'Beedrill',
#   'type': 'BugPoison',
#   'hp': 65.0,
#   'attack': 90.0,
#   'defense': 40.0,
#   'special_attack': 45.0,
#   'special_defense': 80.0,
#   'speed': 75.0},
#  20: {'name': 'BeedrillMega Beedrill',
#   'type': 'BugPoison',
#   'hp': 65.0,
#   'attack': 150.0,
#   'defense': 40.0,
#   'special_attack': 15.0,
#   'special_defense': 80.0,
#   'speed': 145.0},
#  21: {'name': 'Pidgey',
#   'type': 'NormalFlying',
#   'hp': 40.0,
#   'attack': 45.0,
#   'defense': 40.0,
#   'special_attack': 35.0,
#   'special_defense': 35.0,
#   'speed': 56.0},
#  22: {'name': 'Pidgeotto',
#   'type': 'NormalFlying',
#   'hp': 63.0,
#   'attack': 60.0,
#   'defense': 55.0,
#   'special_attack': 50.0,
#   'special_defense': 50.0,
#   'speed': 71.0},
#  23: {'name': 'Pidgeot',
#   'type': 'NormalFlying',
#   'hp': 83.0,
#   'attack': 80.0,
#   'defense': 75.0,
#   'special_attack': 70.0,
#   'special_defense': 70.0,
#   'speed': 101.0},
#  24: {'name': 'PidgeotMega Pidgeot',
#   'type': 'NormalFlying',
#   'hp': 83.0,
#   'attack': 80.0,
#   'defense': 80.0,
#   'special_attack': 135.0,
#   'special_defense': 80.0,
#   'speed': 121.0},
#  25: {'name': 'Rattata',
#   'type': 'Normal',
#   'hp': 30.0,
#   'attack': 56.0,
#   'defense': 35.0,
#   'special_attack': 25.0,
#   'special_defense': 35.0,
#   'speed': 72.0},
#  26: {'name': 'Raticate',
#   'type': 'Normal',
#   'hp': 55.0,
#   'attack': 81.0,
#   'defense': 60.0,
#   'special_attack': 50.0,
#   'special_defense': 70.0,
#   'speed': 97.0},
#  27: {'name': 'Spearow',
#   'type': 'NormalFlying',
#   'hp': 40.0,
#   'attack': 60.0,
#   'defense': 30.0,
#   'special_attack': 31.0,
#   'special_defense': 31.0,
#   'speed': 70.0},
#  28: {'name': 'Fearow',
#   'type': 'NormalFlying',
#   'hp': 65.0,
#   'attack': 90.0,
#   'defense': 65.0,
#   'special_attack': 61.0,
#   'special_defense': 61.0,
#   'speed': 100.0},
#  29: {'name': 'Ekans',
#   'type': 'Poison',
#   'hp': 35.0,
#   'attack': 60.0,
#   'defense': 44.0,
#   'special_attack': 40.0,
#   'special_defense': 54.0,
#   'speed': 55.0},
#  30: {'name': 'Arbok',
#   'type': 'Poison',
#   'hp': 60.0,
#   'attack': 85.0,
#   'defense': 69.0,
#   'special_attack': 65.0,
#   'special_defense': 79.0,
#   'speed': 80.0},
#  31: {'name': 'Pikachu',
#   'type': 'Electric',
#   'hp': 35.0,
#   'attack': 55.0,
#   'defense': 40.0,
#   'special_attack': 50.0,
#   'special_defense': 50.0,
#   'speed': 90.0},
#  32: {'name': 'Raichu',
#   'type': 'Electric',
#   'hp': 60.0,
#   'attack': 90.0,
#   'defense': 55.0,
#   'special_attack': 90.0,
#   'special_defense': 80.0,
#   'speed': 110.0},
#  33: {'name': 'Sandshrew',
#   'type': 'Ground',
#   'hp': 50.0,
#   'attack': 75.0,
#   'defense': 85.0,
#   'special_attack': 20.0,
#   'special_defense': 30.0,
#   'speed': 40.0},
#  34: {'name': 'Sandslash',
#   'type': 'Ground',
#   'hp': 75.0,
#   'attack': 100.0,
#   'defense': 110.0,
#   'special_attack': 45.0,
#   'special_defense': 55.0,
#   'speed': 65.0},
#  35: {'name': 'NidoranF',
#   'type': 'Poison',
#   'hp': 55.0,
#   'attack': 47.0,
#   'defense': 52.0,
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 41.0},
#  36: {'name': 'Nidorina',
#   'type': 'Poison',
#   'hp': 70.0,
#   'attack': 62.0,
#   'defense': 67.0,
#   'special_attack': 55.0,
#   'special_defense': 55.0,
#   'speed': 56.0},
#  37: {'name': 'Nidoqueen',
#   'type': 'PoisonGround',
#   'hp': 90.0,
#   'attack': 92.0,
#   'defense': 87.0,
#   'special_attack': 75.0,
#   'special_defense': 85.0,
#   'speed': 76.0},
#  38: {'name': 'NidoranM',
#   'type': 'Poison',
#   'hp': 46.0,
#   'attack': 57.0,
#   'defense': 40.0,
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 50.0},
#  39: {'name': 'Nidorino',
#   'type': 'Poison',
#   'hp': 61.0,
#   'attack': 72.0,
#   'defense': 57.0,
#   'special_attack': 55.0,
#   'special_defense': 55.0,
#   'speed': 65.0},
#  40: {'name': 'Nidoking',
#   'type': 'PoisonGround',
#   'hp': 81.0,
#   'attack': 102.0,
#   'defense': 77.0,
#   'special_attack': 85.0,
#   'special_defense': 75.0,
#   'speed': 85.0},
#  41: {'name': 'Clefairy',
#   'type': 'Fairy',
#   'hp': 70.0,
#   'attack': 45.0,
#   'defense': 48.0,
#   'special_attack': 60.0,
#   'special_defense': 65.0,
#   'speed': 35.0},
#  42: {'name': 'Clefable',
#   'type': 'Fairy',
#   'hp': 95.0,
#   'attack': 70.0,
#   'defense': 73.0,
#   'special_attack': 95.0,
#   'special_defense': 90.0,
#   'speed': 60.0},
#  43: {'name': 'Vulpix',
#   'type': 'Fire',
#   'hp': 38.0,
#   'attack': 41.0,
#   'defense': 40.0,
#   'special_attack': 50.0,
#   'special_defense': 65.0,
#   'speed': 65.0},
#  44: {'name': 'Ninetales',
#   'type': 'Fire',
#   'hp': 73.0,
#   'attack': 76.0,
#   'defense': 75.0,
#   'special_attack': 81.0,
#   'special_defense': 100.0,
#   'speed': 100.0},
#  45: {'name': 'Jigglypuff',
#   'type': 'NormalFairy',
#   'hp': 115.0,
#   'attack': 45.0,
#   'defense': 20.0,
#   'special_attack': 45.0,
#   'special_defense': 25.0,
#   'speed': 20.0},
#  46: {'name': 'Wigglytuff',
#   'type': 'NormalFairy',
#   'hp': 140.0,
#   'attack': 70.0,
#   'defense': 45.0,
#   'special_attack': 85.0,
#   'special_defense': 50.0,
#   'speed': 45.0},
#  47: {'name': 'Zubat',
#   'type': 'PoisonFlying',
#   'hp': 40.0,
#   'attack': 45.0,
#   'defense': 35.0,
#   'special_attack': 30.0,
#   'special_defense': 40.0,
#   'speed': 55.0},
#  48: {'name': 'Golbat',
#   'type': 'PoisonFlying',
#   'hp': 75.0,
#   'attack': 80.0,
#   'defense': 70.0,
#   'special_attack': 65.0,
#   'special_defense': 75.0,
#   'speed': 90.0},
#  49: {'name': 'Oddish',
#   'type': 'GrassPoison',
#   'hp': 45.0,
#   'attack': 50.0,
#   'defense': 55.0,
#   'special_attack': 75.0,
#   'special_defense': 65.0,
#   'speed': 30.0},
#  50: {'name': 'Gloom',
#   'type': 'GrassPoison',
#   'hp': 60.0,
#   'attack': 65.0,
#   'defense': 70.0,
#   'special_attack': 85.0,
#   'special_defense': 75.0,
#   'speed': 40.0},
#  51: {'name': 'Vileplume',
#   'type': 'GrassPoison',
#   'hp': 75.0,
#   'attack': 80.0,
#   'defense': 85.0,
#   'special_attack': 110.0,
#   'special_defense': 90.0,
#   'speed': 50.0},
#  52: {'name': 'Paras',
#   'type': 'BugGrass',
#   'hp': 35.0,
#   'attack': 70.0,
#   'defense': 55.0,
#   'special_attack': 45.0,
#   'special_defense': 55.0,
#   'speed': 25.0},
#  53: {'name': 'Parasect',
#   'type': 'BugGrass',
#   'hp': 60.0,
#   'attack': 95.0,
#   'defense': 80.0,
#   'special_attack': 60.0,
#   'special_defense': 80.0,
#   'speed': 30.0},
#  54: {'name': 'Venonat',
#   'type': 'BugPoison',
#   'hp': 60.0,
#   'attack': 55.0,
#   'defense': 50.0,
#   'special_attack': 40.0,
#   'special_defense': 55.0,
#   'speed': 45.0},
#  55: {'name': 'Venomoth',
#   'type': 'BugPoison',
#   'hp': 70.0,
#   'attack': 65.0,
#   'defense': 60.0,
#   'special_attack': 90.0,
#   'special_defense': 75.0,
#   'speed': 90.0},
#  56: {'name': 'Diglett',
#   'type': 'Ground',
#   'hp': 10.0,
#   'attack': 55.0,
#   'defense': 25.0,
#   'special_attack': 35.0,
#   'special_defense': 45.0,
#   'speed': 95.0},
#  57: {'name': 'Dugtrio',
#   'type': 'Ground',
#   'hp': 35.0,
#   'attack': 80.0,
#   'defense': 50.0,
#   'special_attack': 50.0,
#   'special_defense': 70.0,
#   'speed': 120.0},
#  58: {'name': 'Meowth',
#   'type': 'Normal',
#   'hp': 40.0,
#   'attack': 45.0,
#   'defense': 35.0,
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 90.0},
#  59: {'name': 'Persian',
#   'type': 'Normal',
#   'hp': 65.0,
#   'attack': 70.0,
#   'defense': 60.0,
#   'special_attack': 65.0,
#   'special_defense': 65.0,
#   'speed': 115.0},
#  60: {'name': 'Psyduck',
#   'type': 'Water',
#   'hp': 50.0,
#   'attack': 52.0,
#   'defense': 48.0,
#   'special_attack': 65.0,
#   'special_defense': 50.0,
#   'speed': 55.0},
#  61: {'name': 'Golduck',
#   'type': 'Water',
#   'hp': 80.0,
#   'attack': 82.0,
#   'defense': 78.0,
#   'special_attack': 95.0,
#   'special_defense': 80.0,
#   'speed': 85.0},
#  62: {'name': 'Mankey',
#   'type': 'Fighting',
#   'hp': 40.0,
#   'attack': 80.0,
#   'defense': 35.0,
#   'special_attack': 35.0,
#   'special_defense': 45.0,
#   'speed': 70.0},
#  63: {'name': 'Primeape',
#   'type': 'Fighting',
#   'hp': 65.0,
#   'attack': 105.0,
#   'defense': 60.0,
#   'special_attack': 60.0,
#   'special_defense': 70.0,
#   'speed': 95.0},
#  64: {'name': 'Growlithe',
#   'type': 'Fire',
#   'hp': 55.0,
#   'attack': 70.0,
#   'defense': 45.0,
#   'special_attack': 70.0,
#   'special_defense': 50.0,
#   'speed': 60.0},
#  65: {'name': 'Arcanine',
#   'type': 'Fire',
#   'hp': 90.0,
#   'attack': 110.0,
#   'defense': 80.0,
#   'special_attack': 100.0,
#   'special_defense': 80.0,
#   'speed': 95.0},
#  66: {'name': 'Poliwag',
#   'type': 'Water',
#   'hp': 40.0,
#   'attack': 50.0,
#   'defense': 40.0,
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 90.0},
#  67: {'name': 'Poliwhirl',
#   'type': 'Water',
#   'hp': 65.0,
#   'attack': 65.0,
#   'defense': 65.0,
#   'special_attack': 50.0,
#   'special_defense': 50.0,
#   'speed': 90.0},
#  68: {'name': 'Poliwrath',
#   'type': 'WaterFighting',
#   'hp': 90.0,
#   'attack': 95.0,
#   'defense': 95.0,
#   'special_attack': 70.0,
#   'special_defense': 90.0,
#   'speed': 70.0},
#  69: {'name': 'Abra',
#   'type': 'Psychic',
#   'hp': 25.0,
#   'attack': 20.0,
#   'defense': 15.0,
#   'special_attack': 105.0,
#   'special_defense': 55.0,
#   'speed': 90.0},
#  70: {'name': 'Kadabra',
#   'type': 'Psychic',
#   'hp': 40.0,
#   'attack': 35.0,
#   'defense': 30.0,
#   'special_attack': 120.0,
#   'special_defense': 70.0,
#   'speed': 105.0},
#  71: {'name': 'Alakazam',
#   'type': 'Psychic',
#   'hp': 55.0,
#   'attack': 50.0,
#   'defense': 45.0,
#   'special_attack': 135.0,
#   'special_defense': 95.0,
#   'speed': 120.0},
#  72: {'name': 'AlakazamMega Alakazam',
#   'type': 'Psychic',
#   'hp': 55.0,
#   'attack': 50.0,
#   'defense': 65.0,
#   'special_attack': 175.0,
#   'special_defense': 95.0,
#   'speed': 150.0},
#  73: {'name': 'Machop',
#   'type': 'Fighting',
#   'hp': 70.0,
#   'attack': 80.0,
#   'defense': 50.0,
#   'special_attack': 35.0,
#   'special_defense': 35.0,
#   'speed': 35.0},
#  74: {'name': 'Machoke',
#   'type': 'Fighting',
#   'hp': 80.0,
#   'attack': 100.0,
#   'defense': 70.0,
#   'special_attack': 50.0,
#   'special_defense': 60.0,
#   'speed': 45.0},
#  75: {'name': 'Machamp',
#   'type': 'Fighting',
#   'hp': 90.0,
#   'attack': 130.0,
#   'defense': 80.0,
#   'special_attack': 65.0,
#   'special_defense': 85.0,
#   'speed': 55.0},
#  76: {'name': 'Bellsprout',
#   'type': 'GrassPoison',
#   'hp': 50.0,
#   'attack': 75.0,
#   'defense': 35.0,
#   'special_attack': 70.0,
#   'special_defense': 30.0,
#   'speed': 40.0},
#  77: {'name': 'Weepinbell',
#   'type': 'GrassPoison',
#   'hp': 65.0,
#   'attack': 90.0,
#   'defense': 50.0,
#   'special_attack': 85.0,
#   'special_defense': 45.0,
#   'speed': 55.0},
#  78: {'name': 'Victreebel',
#   'type': 'GrassPoison',
#   'hp': 80.0,
#   'attack': 105.0,
#   'defense': 65.0,
#   'special_attack': 100.0,
#   'special_defense': 70.0,
#   'speed': 70.0},
#  79: {'name': 'Tentacool',
#   'type': 'WaterPoison',
#   'hp': 40.0,
#   'attack': 40.0,
#   'defense': 35.0,
#   'special_attack': 50.0,
#   'special_defense': 100.0,
#   'speed': 70.0},
#  80: {'name': 'Tentacruel',
#   'type': 'WaterPoison',
#   'hp': 80.0,
#   'attack': 70.0,
#   'defense': 65.0,
#   'special_attack': 80.0,
#   'special_defense': 120.0,
#   'speed': 100.0},
#  81: {'name': 'Geodude',
#   'type': 'RockGround',
#   'hp': 40.0,
#   'attack': 80.0,
#   'defense': 100.0,
#   'special_attack': 30.0,
#   'special_defense': 30.0,
#   'speed': 20.0},
#  82: {'name': 'Graveler',
#   'type': 'RockGround',
#   'hp': 55.0,
#   'attack': 95.0,
#   'defense': 115.0,
#   'special_attack': 45.0,
#   'special_defense': 45.0,
#   'speed': 35.0},
#  83: {'name': 'Golem',
#   'type': 'RockGround',
#   'hp': 80.0,
#   'attack': 120.0,
#   'defense': 130.0,
#   'special_attack': 55.0,
#   'special_defense': 65.0,
#   'speed': 45.0},
#  84: {'name': 'Ponyta',
#   'type': 'Fire',
#   'hp': 50.0,
#   'attack': 85.0,
#   'defense': 55.0,
#   'special_attack': 65.0,
#   'special_defense': 65.0,
#   'speed': 90.0},
#  85: {'name': 'Rapidash',
#   'type': 'Fire',
#   'hp': 65.0,
#   'attack': 100.0,
#   'defense': 70.0,
#   'special_attack': 80.0,
#   'special_defense': 80.0,
#   'speed': 105.0},
#  86: {'name': 'Slowpoke',
#   'type': 'WaterPsychic',
#   'hp': 90.0,
#   'attack': 65.0,
#   'defense': 65.0,
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 15.0},
#  87: {'name': 'Slowbro',
#   'type': 'WaterPsychic',
#   'hp': 95.0,
#   'attack': 75.0,
#   'defense': 110.0,
#   'special_attack': 100.0,
#   'special_defense': 80.0,
#   'speed': 30.0},
#  88: {'name': 'SlowbroMega Slowbro',
#   'type': 'WaterPsychic',
#   'hp': 95.0,
#   'attack': 75.0,
#   'defense': 180.0,
#   'special_attack': 130.0,
#   'special_defense': 80.0,
#   'speed': 30.0},
#  89: {'name': 'Magnemite',
#   'type': 'ElectricSteel',
#   'hp': 25.0,
#   'attack': 35.0,
#   'defense': 70.0,
#   'special_attack': 95.0,
#   'special_defense': 55.0,
#   'speed': 45.0},
#  90: {'name': 'Magneton',
#   'type': 'ElectricSteel',
#   'hp': 50.0,
#   'attack': 60.0,
#   'defense': 95.0,
#   'special_attack': 120.0,
#   'special_defense': 70.0,
#   'speed': 70.0},
#  91: {'name': "Farfetch'd",
#   'type': 'NormalFlying',
#   'hp': 52.0,
#   'attack': 65.0,
#   'defense': 55.0,
#   'special_attack': 58.0,
#   'special_defense': 62.0,
#   'speed': 60.0},
#  92: {'name': 'Doduo',
#   'type': 'NormalFlying',
#   'hp': 35.0,
#   'attack': 85.0,
#   'defense': 45.0,
#   'special_attack': 35.0,
#   'special_defense': 35.0,
#   'speed': 75.0},
#  93: {'name': 'Dodrio',
#   'type': 'NormalFlying',
#   'hp': 60.0,
#   'attack': 110.0,
#   'defense': 70.0,
#   'special_attack': 60.0,
#   'special_defense': 60.0,
#   'speed': 100.0},
#  94: {'name': 'Seel',
#   'type': 'Water',
#   'hp': 65.0,
#   'attack': 45.0,
#   'defense': 55.0,
#   'special_attack': 45.0,
#   'special_defense': 70.0,
#   'speed': 45.0},
#  95: {'name': 'Dewgong',
#   'type': 'WaterIce',
#   'hp': 90.0,
#   'attack': 70.0,
#   'defense': 80.0,
#   'special_attack': 70.0,
#   'special_defense': 95.0,
#   'speed': 70.0},
#  96: {'name': 'Grimer',
#   'type': 'Poison',
#   'hp': 80.0,
#   'attack': 80.0,
#   'defense': 50.0,
#   'special_attack': 40.0,
#   'special_defense': 50.0,
#   'speed': 25.0},
#  97: {'name': 'Muk',
#   'type': 'Poison',
#   'hp': 105.0,
#   'attack': 105.0,
#   'defense': 75.0,
#   'special_attack': 65.0,
#   'special_defense': 100.0,
#   'speed': 50.0},
#  98: {'name': 'Shellder',
#   'type': 'Water',
#   'hp': 30.0,
#   'attack': 65.0,
#   'defense': 100.0,
#   'special_attack': 45.0,
#   'special_defense': 25.0,
#   'speed': 40.0},
#  99: {'name': 'Cloyster',
#   'type': 'WaterIce',
#   'hp': 50.0,
#   'attack': 95.0,
#   'defense': 180.0,
#   'special_attack': 85.0,
#   'special_defense': 45.0,
#   'speed': 70.0},
#  100: {'name': 'Gastly',
#   'type': 'GhostPoison',
#   'hp': 30.0,
#   'attack': 35.0,
#   'defense': 30.0,
#   'special_attack': 100.0,
#   'special_defense': 35.0,
#   'speed': 80.0},
#  101: {'name': 'Haunter',
#   'type': 'GhostPoison',
#   'hp': 45.0,
#   'attack': 50.0,
#   'defense': 45.0,
#   'special_attack': 115.0,
#   'special_defense': 55.0,
#   'speed': 95.0},
#  102: {'name': 'Gengar',
#   'type': 'GhostPoison',
#   'hp': 60.0,
#   'attack': 65.0,
#   'defense': 60.0,
#   'special_attack': 130.0,
#   'special_defense': 75.0,
#   'speed': 110.0},
#  103: {'name': 'GengarMega Gengar',
#   'type': 'GhostPoison',
#   'hp': 60.0,
#   'attack': 65.0,
#   'defense': 80.0,
#   'special_attack': 170.0,
#   'special_defense': 95.0,
#   'speed': 130.0},
#  104: {'name': 'Onix',
#   'type': 'RockGround',
#   'hp': 35.0,
#   'attack': 45.0,
#   'defense': 160.0,
#   'special_attack': 30.0,
#   'special_defense': 45.0,
#   'speed': 70.0},
#  105: {'name': 'Drowzee',
#   'type': 'Psychic',
#   'hp': 60.0,
#   'attack': 48.0,
#   'defense': 45.0,
#   'special_attack': 43.0,
#   'special_defense': 90.0,
#   'speed': 42.0},
#  106: {'name': 'Hypno',
#   'type': 'Psychic',
#   'hp': 85.0,
#   'attack': 73.0,
#   'defense': 70.0,
#   'special_attack': 73.0,
#   'special_defense': 115.0,
#   'speed': 67.0},
#  107: {'name': 'Krabby',
#   'type': 'Water',
#   'hp': 30.0,
#   'attack': 105.0,
#   'defense': 90.0,
#   'special_attack': 25.0,
#   'special_defense': 25.0,
#   'speed': 50.0},
#  108: {'name': 'Kingler',
#   'type': 'Water',
#   'hp': 55.0,
#   'attack': 130.0,
#   'defense': 115.0,
#   'special_attack': 50.0,
#   'special_defense': 50.0,
#   'speed': 75.0},
#  109: {'name': 'Voltorb',
#   'type': 'Electric',
#   'hp': 40.0,
#   'attack': 30.0,
#   'defense': 50.0,
#   'special_attack': 55.0,
#   'special_defense': 55.0,
#   'speed': 100.0},
#  110: {'name': 'Electrode',
#   'type': 'Electric',
#   'hp': 60.0,
#   'attack': 50.0,
#   'defense': 70.0,
#   'special_attack': 80.0,
#   'special_defense': 80.0,
#   'speed': 140.0},
#  111: {'name': 'Exeggcute',
#   'type': 'GrassPsychic',
#   'hp': 60.0,
#   'attack': 40.0,
#   'defense': 80.0,
#   'special_attack': 60.0,
#   'special_defense': 45.0,
#   'speed': 40.0},
#  112: {'name': 'Exeggutor',
#   'type': 'GrassPsychic',
#   'hp': 95.0,
#   'attack': 95.0,
#   'defense': 85.0,
#   'special_attack': 125.0,
#   'special_defense': 65.0,
#   'speed': 55.0},
#  113: {'name': 'Cubone',
#   'type': 'Ground',
#   'hp': 50.0,
#   'attack': 50.0,
#   'defense': 95.0,
#   'special_attack': 40.0,
#   'special_defense': 50.0,
#   'speed': 35.0},
#  114: {'name': 'Marowak',
#   'type': 'Ground',
#   'hp': 60.0,
#   'attack': 80.0,
#   'defense': 110.0,
#   'special_attack': 50.0,
#   'special_defense': 80.0,
#   'speed': 45.0},
#  115: {'name': 'Hitmonlee',
#   'type': 'Fighting',
#   'hp': 50.0,
#   'attack': 120.0,
#   'defense': 53.0,
#   'special_attack': 35.0,
#   'special_defense': 110.0,
#   'speed': 87.0},
#  116: {'name': 'Hitmonchan',
#   'type': 'Fighting',
#   'hp': 50.0,
#   'attack': 105.0,
#   'defense': 79.0,
#   'special_attack': 35.0,
#   'special_defense': 110.0,
#   'speed': 76.0},
#  117: {'name': 'Lickitung',
#   'type': 'Normal',
#   'hp': 90.0,
#   'attack': 55.0,
#   'defense': 75.0,
#   'special_attack': 60.0,
#   'special_defense': 75.0,
#   'speed': 30.0},
#  118: {'name': 'Koffing',
#   'type': 'Poison',
#   'hp': 40.0,
#   'attack': 65.0,
#   'defense': 95.0,
#   'special_attack': 60.0,
#   'special_defense': 45.0,
#   'speed': 35.0},
#  119: {'name': 'Weezing',
#   'type': 'Poison',
#   'hp': 65.0,
#   'attack': 90.0,
#   'defense': 120.0,
#   'special_attack': 85.0,
#   'special_defense': 70.0,
#   'speed': 60.0},
#  120: {'name': 'Rhyhorn',
#   'type': 'GroundRock',
#   'hp': 80.0,
#   'attack': 85.0,
#   'defense': 95.0,
#   'special_attack': 30.0,
#   'special_defense': 30.0,
#   'speed': 25.0},
#  121: {'name': 'Rhydon',
#   'type': 'GroundRock',
#   'hp': 105.0,
#   'attack': 130.0,
#   'defense': 120.0,
#   'special_attack': 45.0,
#   'special_defense': 45.0,
#   'speed': 40.0},
#  122: {'name': 'Chansey',
#   'type': 'Normal',
#   'hp': 250.0,
#   'attack': 5.0,
#   'defense': 5.0,
#   'special_attack': 35.0,
#   'special_defense': 105.0,
#   'speed': 50.0},
#  123: {'name': 'Tangela',
#   'type': 'Grass',
#   'hp': 65.0,
#   'attack': 55.0,
#   'defense': 115.0,
#   'special_attack': 100.0,
#   'special_defense': 40.0,
#   'speed': 60.0},
#  124: {'name': 'Kangaskhan',
#   'type': 'Normal',
#   'hp': 105.0,
#   'attack': 95.0,
#   'defense': 80.0,
#   'special_attack': 40.0,
#   'special_defense': 80.0,
#   'speed': 90.0},
#  125: {'name': 'KangaskhanMega Kangaskhan',
#   'type': 'Normal',
#   'hp': 105.0,
#   'attack': 125.0,
#   'defense': 100.0,
#   'special_attack': 60.0,
#   'special_defense': 100.0,
#   'speed': 100.0},
#  126: {'name': 'Horsea',
#   'type': 'Water',
#   'hp': 30.0,
#   'attack': 40.0,
#   'defense': 70.0,
#   'special_attack': 70.0,
#   'special_defense': 25.0,
#   'speed': 60.0},
#  127: {'name': 'Seadra',
#   'type': 'Water',
#   'hp': 55.0,
#   'attack': 65.0,
#   'defense': 95.0,
#   'special_attack': 95.0,
#   'special_defense': 45.0,
#   'speed': 85.0},
#  128: {'name': 'Goldeen',
#   'type': 'Water',
#   'hp': 45.0,
#   'attack': 67.0,
#   'defense': 60.0,
#   'special_attack': 35.0,
#   'special_defense': 50.0,
#   'speed': 63.0},
#  129: {'name': 'Seaking',
#   'type': 'Water',
#   'hp': 80.0,
#   'attack': 92.0,
#   'defense': 65.0,
#   'special_attack': 65.0,
#   'special_defense': 80.0,
#   'speed': 68.0},
#  130: {'name': 'Staryu',
#   'type': 'Water',
#   'hp': 30.0,
#   'attack': 45.0,
#   'defense': 55.0,
#   'special_attack': 70.0,
#   'special_defense': 55.0,
#   'speed': 85.0},
#  131: {'name': 'Starmie',
#   'type': 'WaterPsychic',
#   'hp': 60.0,
#   'attack': 75.0,
#   'defense': 85.0,
#   'special_attack': 100.0,
#   'special_defense': 85.0,
#   'speed': 115.0},
#  132: {'name': 'Mr. Mime',
#   'type': 'PsychicFairy',
#   'hp': 40.0,
#   'attack': 45.0,
#   'defense': 65.0,
#   'special_attack': 100.0,
#   'special_defense': 120.0,
#   'speed': 90.0},
#  133: {'name': 'Scyther',
#   'type': 'BugFlying',
#   'hp': 70.0,
#   'attack': 110.0,
#   'defense': 80.0,
#   'special_attack': 55.0,
#   'special_defense': 80.0,
#   'speed': 105.0},
#  134: {'name': 'Jynx',
#   'type': 'IcePsychic',
#   'hp': 65.0,
#   'attack': 50.0,
#   'defense': 35.0,
#   'special_attack': 115.0,
#   'special_defense': 95.0,
#   'speed': 95.0},
#  135: {'name': 'Electabuzz',
#   'type': 'Electric',
#   'hp': 65.0,
#   'attack': 83.0,
#   'defense': 57.0,
#   'special_attack': 95.0,
#   'special_defense': 85.0,
#   'speed': 105.0},
#  136: {'name': 'Magmar',
#   'type': 'Fire',
#   'hp': 65.0,
#   'attack': 95.0,
#   'defense': 57.0,
#   'special_attack': 100.0,
#   'special_defense': 85.0,
#   'speed': 93.0},
#  137: {'name': 'Pinsir',
#   'type': 'Bug',
#   'hp': 65.0,
#   'attack': 125.0,
#   'defense': 100.0,
#   'special_attack': 55.0,
#   'special_defense': 70.0,
#   'speed': 85.0},
#  138: {'name': 'PinsirMega Pinsir',
#   'type': 'BugFlying',
#   'hp': 65.0,
#   'attack': 155.0,
#   'defense': 120.0,
#   'special_attack': 65.0,
#   'special_defense': 90.0,
#   'speed': 105.0},
#  139: {'name': 'Tauros',
#   'type': 'Normal',
#   'hp': 75.0,
#   'attack': 100.0,
#   'defense': 95.0,
#   'special_attack': 40.0,
#   'special_defense': 70.0,
#   'speed': 110.0},
#  140: {'name': 'Magikarp',
#   'type': 'Water',
#   'hp': 20.0,
#   'attack': 10.0,
#   'defense': 55.0,
#   'special_attack': 15.0,
#   'special_defense': 20.0,
#   'speed': 80.0},
#  141: {'name': 'Gyarados',
#   'type': 'WaterFlying',
#   'hp': 95.0,
#   'attack': 125.0,
#   'defense': 79.0,
#   'special_attack': 60.0,
#   'special_defense': 100.0,
#   'speed': 81.0},
#  142: {'name': 'GyaradosMega Gyarados',
#   'type': 'WaterDark',
#   'hp': 95.0,
#   'attack': 155.0,
#   'defense': 109.0,
#   'special_attack': 70.0,
#   'special_defense': 130.0,
#   'speed': 81.0},
#  143: {'name': 'Lapras',
#   'type': 'WaterIce',
#   'hp': 130.0,
#   'attack': 85.0,
#   'defense': 80.0,
#   'special_attack': 85.0,
#   'special_defense': 95.0,
#   'speed': 60.0},
#  144: {'name': 'Ditto',
#   'type': 'Normal',
#   'hp': 48.0,
#   'attack': 48.0,
#   'defense': 48.0,
#   'special_attack': 48.0,
#   'special_defense': 48.0,
#   'speed': 48.0},
#  145: {'name': 'Eevee',
#   'type': 'Normal',
#   'hp': 55.0,
#   'attack': 55.0,
#   'defense': 50.0,
#   'special_attack': 45.0,
#   'special_defense': 65.0,
#   'speed': 55.0},
#  146: {'name': 'Vaporeon',
#   'type': 'Water',
#   'hp': 130.0,
#   'attack': 65.0,
#   'defense': 60.0,
#   'special_attack': 110.0,
#   'special_defense': 95.0,
#   'speed': 65.0},
#  147: {'name': 'Jolteon',
#   'type': 'Electric',
#   'hp': 65.0,
#   'attack': 65.0,
#   'defense': 60.0,
#   'special_attack': 110.0,
#   'special_defense': 95.0,
#   'speed': 130.0},
#  148: {'name': 'Flareon',
#   'type': 'Fire',
#   'hp': 65.0,
#   'attack': 130.0,
#   'defense': 60.0,
#   'special_attack': 95.0,
#   'special_defense': 110.0,
#   'speed': 65.0},
#  149: {'name': 'Porygon',
#   'type': 'Normal',
#   'hp': 65.0,
#   'attack': 60.0,
#   'defense': 70.0,
#   'special_attack': 85.0,
#   'special_defense': 75.0,
#   'speed': 40.0},
#  150: {'name': 'Omanyte',
#   'type': 'RockWater',
#   'hp': 35.0,
#   'attack': 40.0,
#   'defense': 100.0,
#   'special_attack': 90.0,
#   'special_defense': 55.0,
#   'speed': 35.0},
#  151: {'name': 'Omastar',
#   'type': 'RockWater',
#   'hp': 70.0,
#   'attack': 60.0,
#   'defense': 125.0,
#   'special_attack': 115.0,
#   'special_defense': 70.0,
#   'speed': 55.0},
#  152: {'name': 'Kabuto',
#   'type': 'RockWater',
#   'hp': 30.0,
#   'attack': 80.0,
#   'defense': 90.0,
#   'special_attack': 55.0,
#   'special_defense': 45.0,
#   'speed': 55.0},
#  153: {'name': 'Kabutops',
#   'type': 'RockWater',
#   'hp': 60.0,
#   'attack': 115.0,
#   'defense': 105.0,
#   'special_attack': 65.0,
#   'special_defense': 70.0,
#   'speed': 80.0},
#  154: {'name': 'Aerodactyl',
#   'type': 'RockFlying',
#   'hp': 80.0,
#   'attack': 105.0,
#   'defense': 65.0,
#   'special_attack': 60.0,
#   'special_defense': 75.0,
#   'speed': 130.0},
#  155: {'name': 'AerodactylMega Aerodactyl',
#   'type': 'RockFlying',
#   'hp': 80.0,
#   'attack': 135.0,
#   'defense': 85.0,
#   'special_attack': 70.0,
#   'special_defense': 95.0,
#   'speed': 150.0},
#  156: {'name': 'Snorlax',
#   'type': 'Normal',
#   'hp': 160.0,
#   'attack': 110.0,
#   'defense': 65.0,
#   'special_attack': 65.0,
#   'special_defense': 110.0,
#   'speed': 30.0},
#  157: {'name': 'Articuno',
#   'type': 'IceFlying',
#   'hp': 90.0,
#   'attack': 85.0,
#   'defense': 100.0,
#   'special_attack': 95.0,
#   'special_defense': 125.0,
#   'speed': 85.0},
#  158: {'name': 'Zapdos',
#   'type': 'ElectricFlying',
#   'hp': 90.0,
#   'attack': 90.0,
#   'defense': 85.0,
#   'special_attack': 125.0,
#   'special_defense': 90.0,
#   'speed': 100.0},
#  159: {'name': 'Moltres',
#   'type': 'FireFlying',
#   'hp': 90.0,
#   'attack': 100.0,
#   'defense': 90.0,
#   'special_attack': 125.0,
#   'special_defense': 85.0,
#   'speed': 90.0},
#  160: {'name': 'Dratini',
#   'type': 'Dragon',
#   'hp': 41.0,
#   'attack': 64.0,
#   'defense': 45.0,
#   'special_attack': 50.0,
#   'special_defense': 50.0,
#   'speed': 50.0},
#  161: {'name': 'Dragonair',
#   'type': 'Dragon',
#   'hp': 61.0,
#   'attack': 84.0,
#   'defense': 65.0,
#   'special_attack': 70.0,
#   'special_defense': 70.0,
#   'speed': 70.0},
#  162: {'name': 'Dragonite',
#   'type': 'DragonFlying',
#   'hp': 91.0,
#   'attack': 134.0,
#   'defense': 95.0,
#   'special_attack': 100.0,
#   'special_defense': 100.0,
#   'speed': 80.0},
#  163: {'name': 'Mewtwo',
#   'type': 'Psychic',
#   'hp': 106.0,
#   'attack': 110.0,
#   'defense': 90.0,
#   'special_attack': 154.0,
#   'special_defense': 90.0,
#   'speed': 130.0},
#  164: {'name': 'MewtwoMega Mewtwo X',
#   'type': 'PsychicFighting',
#   'hp': 126.0,
#   'attack': 190.0,
#   'defense': 100.0,
#   'special_attack': 154.0,
#   'special_defense': 100.0,
#   'speed': 130.0},
#  165: {'name': 'MewtwoMega Mewtwo Y',
#   'type': 'Psychic',
#   'hp': 106.0,
#   'attack': 150.0,
#   'defense': 70.0,
#   'special_attack': 194.0,
#   'special_defense': 120.0,
#   'speed': 140.0},
#  166: {'name': 'Mew',
#   'type': 'Psychic',
#   'hp': 100.0,
#   'attack': 100.0,
#   'defense': 100.0,
#   'special_attack': 100.0,
#   'special_defense': 100.0,
#   'speed': 100.0},
#  167: {'name': 'Chikorita',
#   'type': 'Grass',
#   'hp': 45.0,
#   'attack': 49.0,
#   'defense': 65.0,
#   'special_attack': 49.0,
#   'special_defense': 65.0,
#   'speed': 45.0},
#  168: {'name': 'Bayleef',
#   'type': 'Grass',
#   'hp': 60.0,
#   'attack': 62.0,
#   'defense': 80.0,
#   'special_attack': 63.0,
#   'special_defense': 80.0,
#   'speed': 60.0},
#  169: {'name': 'Meganium',
#   'type': 'Grass',
#   'hp': 80.0,
#   'attack': 82.0,
#   'defense': 100.0,
#   'special_attack': 83.0,
#   'special_defense': 100.0,
#   'speed': 80.0},
#  170: {'name': 'Cyndaquil',
#   'type': 'Fire',
#   'hp': 39.0,
#   'attack': 52.0,
#   'defense': 43.0,
#   'special_attack': 60.0,
#   'special_defense': 50.0,
#   'speed': 65.0},
#  171: {'name': 'Quilava',
#   'type': 'Fire',
#   'hp': 58.0,
#   'attack': 64.0,
#   'defense': 58.0,
#   'special_attack': 80.0,
#   'special_defense': 65.0,
#   'speed': 80.0},
#  172: {'name': 'Typhlosion',
#   'type': 'Fire',
#   'hp': 78.0,
#   'attack': 84.0,
#   'defense': 78.0,
#   'special_attack': 109.0,
#   'special_defense': 85.0,
#   'speed': 100.0},
#  173: {'name': 'Totodile',
#   'type': 'Water',
#   'hp': 50.0,
#   'attack': 65.0,
#   'defense': 64.0,
#   'special_attack': 44.0,
#   'special_defense': 48.0,
#   'speed': 43.0},
#  174: {'name': 'Croconaw',
#   'type': 'Water',
#   'hp': 65.0,
#   'attack': 80.0,
#   'defense': 80.0,
#   'special_attack': 59.0,
#   'special_defense': 63.0,
#   'speed': 58.0},
#  175: {'name': 'Feraligatr',
#   'type': 'Water',
#   'hp': 85.0,
#   'attack': 105.0,
#   'defense': 100.0,
#   'special_attack': 79.0,
#   'special_defense': 83.0,
#   'speed': 78.0},
#  176: {'name': 'Sentret',
#   'type': 'Normal',
#   'hp': 35.0,
#   'attack': 46.0,
#   'defense': 34.0,
#   'special_attack': 35.0,
#   'special_defense': 45.0,
#   'speed': 20.0},
#  177: {'name': 'Furret',
#   'type': 'Normal',
#   'hp': 85.0,
#   'attack': 76.0,
#   'defense': 64.0,
#   'special_attack': 45.0,
#   'special_defense': 55.0,
#   'speed': 90.0},
#  178: {'name': 'Hoothoot',
#   'type': 'NormalFlying',
#   'hp': 60.0,
#   'attack': 30.0,
#   'defense': 30.0,
#   'special_attack': 36.0,
#   'special_defense': 56.0,
#   'speed': 50.0},
#  179: {'name': 'Noctowl',
#   'type': 'NormalFlying',
#   'hp': 100.0,
#   'attack': 50.0,
#   'defense': 50.0,
#   'special_attack': 76.0,
#   'special_defense': 96.0,
#   'speed': 70.0},
#  180: {'name': 'Ledyba',
#   'type': 'BugFlying',
#   'hp': 40.0,
#   'attack': 20.0,
#   'defense': 30.0,
#   'special_attack': 40.0,
#   'special_defense': 80.0,
#   'speed': 55.0},
#  181: {'name': 'Ledian',
#   'type': 'BugFlying',
#   'hp': 55.0,
#   'attack': 35.0,
#   'defense': 50.0,
#   'special_attack': 55.0,
#   'special_defense': 110.0,
#   'speed': 85.0},
#  182: {'name': 'Spinarak',
#   'type': 'BugPoison',
#   'hp': 40.0,
#   'attack': 60.0,
#   'defense': 40.0,
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 30.0},
#  183: {'name': 'Ariados',
#   'type': 'BugPoison',
#   'hp': 70.0,
#   'attack': 90.0,
#   'defense': 70.0,
#   'special_attack': 60.0,
#   'special_defense': 60.0,
#   'speed': 40.0},
#  184: {'name': 'Crobat',
#   'type': 'PoisonFlying',
#   'hp': 85.0,
#   'attack': 90.0,
#   'defense': 80.0,
#   'special_attack': 70.0,
#   'special_defense': 80.0,
#   'speed': 130.0},
#  185: {'name': 'Chinchou',
#   'type': 'WaterElectric',
#   'hp': 75.0,
#   'attack': 38.0,
#   'defense': 38.0,
#   'special_attack': 56.0,
#   'special_defense': 56.0,
#   'speed': 67.0},
#  186: {'name': 'Lanturn',
#   'type': 'WaterElectric',
#   'hp': 125.0,
#   'attack': 58.0,
#   'defense': 58.0,
#   'special_attack': 76.0,
#   'special_defense': 76.0,
#   'speed': 67.0},
#  187: {'name': 'Pichu',
#   'type': 'Electric',
#   'hp': 20.0,
#   'attack': 40.0,
#   'defense': 15.0,
#   'special_attack': 35.0,
#   'special_defense': 35.0,
#   'speed': 60.0},
#  188: {'name': 'Cleffa',
#   'type': 'Fairy',
#   'hp': 50.0,
#   'attack': 25.0,
#   'defense': 28.0,
#   'special_attack': 45.0,
#   'special_defense': 55.0,
#   'speed': 15.0},
#  189: {'name': 'Igglybuff',
#   'type': 'NormalFairy',
#   'hp': 90.0,
#   'attack': 30.0,
#   'defense': 15.0,
#   'special_attack': 40.0,
#   'special_defense': 20.0,
#   'speed': 15.0},
#  190: {'name': 'Togepi',
#   'type': 'Fairy',
#   'hp': 35.0,
#   'attack': 20.0,
#   'defense': 65.0,
#   'special_attack': 40.0,
#   'special_defense': 65.0,
#   'speed': 20.0},
#  191: {'name': 'Togetic',
#   'type': 'FairyFlying',
#   'hp': 55.0,
#   'attack': 40.0,
#   'defense': 85.0,
#   'special_attack': 80.0,
#   'special_defense': 105.0,
#   'speed': 40.0},
#  192: {'name': 'Natu',
#   'type': 'PsychicFlying',
#   'hp': 40.0,
#   'attack': 50.0,
#   'defense': 45.0,
#   'special_attack': 70.0,
#   'special_defense': 45.0,
#   'speed': 70.0},
#  193: {'name': 'Xatu',
#   'type': 'PsychicFlying',
#   'hp': 65.0,
#   'attack': 75.0,
#   'defense': 70.0,
#   'special_attack': 95.0,
#   'special_defense': 70.0,
#   'speed': 95.0},
#  194: {'name': 'Mareep',
#   'type': 'Electric',
#   'hp': 55.0,
#   'attack': 40.0,
#   'defense': 40.0,
#   'special_attack': 65.0,
#   'special_defense': 45.0,
#   'speed': 35.0},
#  195: {'name': 'Flaaffy',
#   'type': 'Electric',
#   'hp': 70.0,
#   'attack': 55.0,
#   'defense': 55.0,
#   'special_attack': 80.0,
#   'special_defense': 60.0,
#   'speed': 45.0},
#  196: {'name': 'Ampharos',
#   'type': 'Electric',
#   'hp': 90.0,
#   'attack': 75.0,
#   'defense': 85.0,
#   'special_attack': 115.0,
#   'special_defense': 90.0,
#   'speed': 55.0},
#  197: {'name': 'AmpharosMega Ampharos',
#   'type': 'ElectricDragon',
#   'hp': 90.0,
#   'attack': 95.0,
#   'defense': 105.0,
#   'special_attack': 165.0,
#   'special_defense': 110.0,
#   'speed': 45.0},
#  198: {'name': 'Bellossom',
#   'type': 'Grass',
#   'hp': 75.0,
#   'attack': 80.0,
#   'defense': 95.0,
#   'special_attack': 90.0,
#   'special_defense': 100.0,
#   'speed': 50.0},
#  199: {'name': 'Marill',
#   'type': 'WaterFairy',
#   'hp': 70.0,
#   'attack': 20.0,
#   'defense': 50.0,
#   'special_attack': 20.0,
#   'special_defense': 50.0,
#   'speed': 40.0},
#  200: {'name': 'Azumarill',
#   'type': 'WaterFairy',
#   'hp': 100.0,
#   'attack': 50.0,
#   'defense': 80.0,
#   'special_attack': 60.0,
#   'special_defense': 80.0,
#   'speed': 50.0},
#  201: {'name': 'Sudowoodo',
#   'type': 'Rock',
#   'hp': 70.0,
#   'attack': 100.0,
#   'defense': 115.0,
#   'special_attack': 30.0,
#   'special_defense': 65.0,
#   'speed': 30.0},
#  202: {'name': 'Politoed',
#   'type': 'Water',
#   'hp': 90.0,
#   'attack': 75.0,
#   'defense': 75.0,
#   'special_attack': 90.0,
#   'special_defense': 100.0,
#   'speed': 70.0},
#  203: {'name': 'Hoppip',
#   'type': 'GrassFlying',
#   'hp': 35.0,
#   'attack': 35.0,
#   'defense': 40.0,
#   'special_attack': 35.0,
#   'special_defense': 55.0,
#   'speed': 50.0},
#  204: {'name': 'Skiploom',
#   'type': 'GrassFlying',
#   'hp': 55.0,
#   'attack': 45.0,
#   'defense': 50.0,
#   'special_attack': 45.0,
#   'special_defense': 65.0,
#   'speed': 80.0},
#  205: {'name': 'Jumpluff',
#   'type': 'GrassFlying',
#   'hp': 75.0,
#   'attack': 55.0,
#   'defense': 70.0,
#   'special_attack': 55.0,
#   'special_defense': 95.0,
#   'speed': 110.0},
#  206: {'name': 'Aipom',
#   'type': 'Normal',
#   'hp': 55.0,
#   'attack': 70.0,
#   'defense': 55.0,
#   'special_attack': 40.0,
#   'special_defense': 55.0,
#   'speed': 85.0},
#  207: {'name': 'Sunkern',
#   'type': 'Grass',
#   'hp': 30.0,
#   'attack': 30.0,
#   'defense': 30.0,
#   'special_attack': 30.0,
#   'special_defense': 30.0,
#   'speed': 30.0},
#  208: {'name': 'Sunflora',
#   'type': 'Grass',
#   'hp': 75.0,
#   'attack': 75.0,
#   'defense': 55.0,
#   'special_attack': 105.0,
#   'special_defense': 85.0,
#   'speed': 30.0},
#  209: {'name': 'Yanma',
#   'type': 'BugFlying',
#   'hp': 65.0,
#   'attack': 65.0,
#   'defense': 45.0,
#   'special_attack': 75.0,
#   'special_defense': 45.0,
#   'speed': 95.0},
#  210: {'name': 'Wooper',
#   'type': 'WaterGround',
#   'hp': 55.0,
#   'attack': 45.0,
#   'defense': 45.0,
#   'special_attack': 25.0,
#   'special_defense': 25.0,
#   'speed': 15.0},
#  211: {'name': 'Quagsire',
#   'type': 'WaterGround',
#   'hp': 95.0,
#   'attack': 85.0,
#   'defense': 85.0,
#   'special_attack': 65.0,
#   'special_defense': 65.0,
#   'speed': 35.0},
#  212: {'name': 'Espeon',
#   'type': 'Psychic',
#   'hp': 65.0,
#   'attack': 65.0,
#   'defense': 60.0,
#   'special_attack': 130.0,
#   'special_defense': 95.0,
#   'speed': 110.0},
#  213: {'name': 'Umbreon',
#   'type': 'Dark',
#   'hp': 95.0,
#   'attack': 65.0,
#   'defense': 110.0,
#   'special_attack': 60.0,
#   'special_defense': 130.0,
#   'speed': 65.0},
#  214: {'name': 'Murkrow',
#   'type': 'DarkFlying',
#   'hp': 60.0,
#   'attack': 85.0,
#   'defense': 42.0,
#   'special_attack': 85.0,
#   'special_defense': 42.0,
#   'speed': 91.0},
#  215: {'name': 'Slowking',
#   'type': 'WaterPsychic',
#   'hp': 95.0,
#   'attack': 75.0,
#   'defense': 80.0,
#   'special_attack': 100.0,
#   'special_defense': 110.0,
#   'speed': 30.0},
#  216: {'name': 'Misdreavus',
#   'type': 'Ghost',
#   'hp': 60.0,
#   'attack': 60.0,
#   'defense': 60.0,
#   'special_attack': 85.0,
#   'special_defense': 85.0,
#   'speed': 85.0},
#  217: {'name': 'Unown',
#   'type': 'Psychic',
#   'hp': 48.0,
#   'attack': 72.0,
#   'defense': 48.0,
#   'special_attack': 72.0,
#   'special_defense': 48.0,
#   'speed': 48.0},
#  218: {'name': 'Wobbuffet',
#   'type': 'Psychic',
#   'hp': 190.0,
#   'attack': 33.0,
#   'defense': 58.0,
#   'special_attack': 33.0,
#   'special_defense': 58.0,
#   'speed': 33.0},
#  219: {'name': 'Girafarig',
#   'type': 'NormalPsychic',
#   'hp': 70.0,
#   'attack': 80.0,
#   'defense': 65.0,
#   'special_attack': 90.0,
#   'special_defense': 65.0,
#   'speed': 85.0},
#  220: {'name': 'Pineco',
#   'type': 'Bug',
#   'hp': 50.0,
#   'attack': 65.0,
#   'defense': 90.0,
#   'special_attack': 35.0,
#   'special_defense': 35.0,
#   'speed': 15.0},
#  221: {'name': 'Forretress',
#   'type': 'BugSteel',
#   'hp': 75.0,
#   'attack': 90.0,
#   'defense': 140.0,
#   'special_attack': 60.0,
#   'special_defense': 60.0,
#   'speed': 40.0},
#  222: {'name': 'Dunsparce',
#   'type': 'Normal',
#   'hp': 100.0,
#   'attack': 70.0,
#   'defense': 70.0,
#   'special_attack': 65.0,
#   'special_defense': 65.0,
#   'speed': 45.0},
#  223: {'name': 'Gligar',
#   'type': 'GroundFlying',
#   'hp': 65.0,
#   'attack': 75.0,
#   'defense': 105.0,
#   'special_attack': 35.0,
#   'special_defense': 65.0,
#   'speed': 85.0},
#  224: {'name': 'Steelix',
#   'type': 'SteelGround',
#   'hp': 75.0,
#   'attack': 85.0,
#   'defense': 200.0,
#   'special_attack': 55.0,
#   'special_defense': 65.0,
#   'speed': 30.0},
#  225: {'name': 'SteelixMega Steelix',
#   'type': 'SteelGround',
#   'hp': 75.0,
#   'attack': 125.0,
#   'defense': 230.0,
#   'special_attack': 55.0,
#   'special_defense': 95.0,
#   'speed': 30.0},
#  226: {'name': 'Snubbull',
#   'type': 'Fairy',
#   'hp': 60.0,
#   'attack': 80.0,
#   'defense': 50.0,
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 30.0},
#  227: {'name': 'Granbull',
#   'type': 'Fairy',
#   'hp': 90.0,
#   'attack': 120.0,
#   'defense': 75.0,
#   'special_attack': 60.0,
#   'special_defense': 60.0,
#   'speed': 45.0},
#  228: {'name': 'Qwilfish',
#   'type': 'WaterPoison',
#   'hp': 65.0,
#   'attack': 95.0,
#   'defense': 75.0,
#   'special_attack': 55.0,
#   'special_defense': 55.0,
#   'speed': 85.0},
#  229: {'name': 'Scizor',
#   'type': 'BugSteel',
#   'hp': 70.0,
#   'attack': 130.0,
#   'defense': 100.0,
#   'special_attack': 55.0,
#   'special_defense': 80.0,
#   'speed': 65.0},
#  230: {'name': 'ScizorMega Scizor',
#   'type': 'BugSteel',
#   'hp': 70.0,
#   'attack': 150.0,
#   'defense': 140.0,
#   'special_attack': 65.0,
#   'special_defense': 100.0,
#   'speed': 75.0},
#  231: {'name': 'Shuckle',
#   'type': 'BugRock',
#   'hp': 20.0,
#   'attack': 10.0,
#   'defense': 230.0,
#   'special_attack': 10.0,
#   'special_defense': 230.0,
#   'speed': 5.0},
#  232: {'name': 'Heracross',
#   'type': 'BugFighting',
#   'hp': 80.0,
#   'attack': 125.0,
#   'defense': 75.0,
#   'special_attack': 40.0,
#   'special_defense': 95.0,
#   'speed': 85.0},
#  233: {'name': 'HeracrossMega Heracross',
#   'type': 'BugFighting',
#   'hp': 80.0,
#   'attack': 185.0,
#   'defense': 115.0,
#   'special_attack': 40.0,
#   'special_defense': 105.0,
#   'speed': 75.0},
#  234: {'name': 'Sneasel',
#   'type': 'DarkIce',
#   'hp': 55.0,
#   'attack': 95.0,
#   'defense': 55.0,
#   'special_attack': 35.0,
#   'special_defense': 75.0,
#   'speed': 115.0},
#  235: {'name': 'Teddiursa',
#   'type': 'Normal',
#   'hp': 60.0,
#   'attack': 80.0,
#   'defense': 50.0,
#   'special_attack': 50.0,
#   'special_defense': 50.0,
#   'speed': 40.0},
#  236: {'name': 'Ursaring',
#   'type': 'Normal',
#   'hp': 90.0,
#   'attack': 130.0,
#   'defense': 75.0,
#   'special_attack': 75.0,
#   'special_defense': 75.0,
#   'speed': 55.0},
#  237: {'name': 'Slugma',
#   'type': 'Fire',
#   'hp': 40.0,
#   'attack': 40.0,
#   'defense': 40.0,
#   'special_attack': 70.0,
#   'special_defense': 40.0,
#   'speed': 20.0},
#  238: {'name': 'Magcargo',
#   'type': 'FireRock',
#   'hp': 50.0,
#   'attack': 50.0,
#   'defense': 120.0,
#   'special_attack': 80.0,
#   'special_defense': 80.0,
#   'speed': 30.0},
#  239: {'name': 'Swinub',
#   'type': 'IceGround',
#   'hp': 50.0,
#   'attack': 50.0,
#   'defense': 40.0,
#   'special_attack': 30.0,
#   'special_defense': 30.0,
#   'speed': 50.0},
#  240: {'name': 'Piloswine',
#   'type': 'IceGround',
#   'hp': 100.0,
#   'attack': 100.0,
#   'defense': 80.0,
#   'special_attack': 60.0,
#   'special_defense': 60.0,
#   'speed': 50.0},
#  241: {'name': 'Corsola',
#   'type': 'WaterRock',
#   'hp': 55.0,
#   'attack': 55.0,
#   'defense': 85.0,
#   'special_attack': 65.0,
#   'special_defense': 85.0,
#   'speed': 35.0},
#  242: {'name': 'Remoraid',
#   'type': 'Water',
#   'hp': 35.0,
#   'attack': 65.0,
#   'defense': 35.0,
#   'special_attack': 65.0,
#   'special_defense': 35.0,
#   'speed': 65.0},
#  243: {'name': 'Octillery',
#   'type': 'Water',
#   'hp': 75.0,
#   'attack': 105.0,
#   'defense': 75.0,
#   'special_attack': 105.0,
#   'special_defense': 75.0,
#   'speed': 45.0},
#  244: {'name': 'Delibird',
#   'type': 'IceFlying',
#   'hp': 45.0,
#   'attack': 55.0,
#   'defense': 45.0,
#   'special_attack': 65.0,
#   'special_defense': 45.0,
#   'speed': 75.0},
#  245: {'name': 'Mantine',
#   'type': 'WaterFlying',
#   'hp': 65.0,
#   'attack': 40.0,
#   'defense': 70.0,
#   'special_attack': 80.0,
#   'special_defense': 140.0,
#   'speed': 70.0},
#  246: {'name': 'Skarmory',
#   'type': 'SteelFlying',
#   'hp': 65.0,
#   'attack': 80.0,
#   'defense': 140.0,
#   'special_attack': 40.0,
#   'special_defense': 70.0,
#   'speed': 70.0},
#  247: {'name': 'Houndour',
#   'type': 'DarkFire',
#   'hp': 45.0,
#   'attack': 60.0,
#   'defense': 30.0,
#   'special_attack': 80.0,
#   'special_defense': 50.0,
#   'speed': 65.0},
#  248: {'name': 'Houndoom',
#   'type': 'DarkFire',
#   'hp': 75.0,
#   'attack': 90.0,
#   'defense': 50.0,
#   'special_attack': 110.0,
#   'special_defense': 80.0,
#   'speed': 95.0},
#  249: {'name': 'HoundoomMega Houndoom',
#   'type': 'DarkFire',
#   'hp': 75.0,
#   'attack': 90.0,
#   'defense': 90.0,
#   'special_attack': 140.0,
#   'special_defense': 90.0,
#   'speed': 115.0},
#  250: {'name': 'Kingdra',
#   'type': 'WaterDragon',
#   'hp': 75.0,
#   'attack': 95.0,
#   'defense': 95.0,
#   'special_attack': 95.0,
#   'special_defense': 95.0,
#   'speed': 85.0},
#  251: {'name': 'Phanpy',
#   'type': 'Ground',
#   'hp': 90.0,
#   'attack': 60.0,
#   'defense': 60.0,
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 40.0},
#  252: {'name': 'Donphan',
#   'type': 'Ground',
#   'hp': 90.0,
#   'attack': 120.0,
#   'defense': 120.0,
#   'special_attack': 60.0,
#   'special_defense': 60.0,
#   'speed': 50.0},
#  253: {'name': 'Porygon2',
#   'type': 'Normal',
#   'hp': 85.0,
#   'attack': 80.0,
#   'defense': 90.0,
#   'special_attack': 105.0,
#   'special_defense': 95.0,
#   'speed': 60.0},
#  254: {'name': 'Stantler',
#   'type': 'Normal',
#   'hp': 73.0,
#   'attack': 95.0,
#   'defense': 62.0,
#   'special_attack': 85.0,
#   'special_defense': 65.0,
#   'speed': 85.0},
#  255: {'name': 'Smeargle',
#   'type': 'Normal',
#   'hp': 55.0,
#   'attack': 20.0,
#   'defense': 35.0,
#   'special_attack': 20.0,
#   'special_defense': 45.0,
#   'speed': 75.0},
#  256: {'name': 'Tyrogue',
#   'type': 'Fighting',
#   'hp': 35.0,
#   'attack': 35.0,
#   'defense': 35.0,
#   'special_attack': 35.0,
#   'special_defense': 35.0,
#   'speed': 35.0},
#  257: {'name': 'Hitmontop',
#   'type': 'Fighting',
#   'hp': 50.0,
#   'attack': 95.0,
#   'defense': 95.0,
#   'special_attack': 35.0,
#   'special_defense': 110.0,
#   'speed': 70.0},
#  258: {'name': 'Smoochum',
#   'type': 'IcePsychic',
#   'hp': 45.0,
#   'attack': 30.0,
#   'defense': 15.0,
#   'special_attack': 85.0,
#   'special_defense': 65.0,
#   'speed': 65.0},
#  259: {'name': 'Elekid',
#   'type': 'Electric',
#   'hp': 45.0,
#   'attack': 63.0,
#   'defense': 37.0,
#   'special_attack': 65.0,
#   'special_defense': 55.0,
#   'speed': 95.0},
#  260: {'name': 'Magby',
#   'type': 'Fire',
#   'hp': 45.0,
#   'attack': 75.0,
#   'defense': 37.0,
#   'special_attack': 70.0,
#   'special_defense': 55.0,
#   'speed': 83.0},
#  261: {'name': 'Miltank',
#   'type': 'Normal',
#   'hp': 95.0,
#   'attack': 80.0,
#   'defense': 105.0,
#   'special_attack': 40.0,
#   'special_defense': 70.0,
#   'speed': 100.0},
#  262: {'name': 'Blissey',
#   'type': 'Normal',
#   'hp': 255.0,
#   'attack': 10.0,
#   'defense': 10.0,
#   'special_attack': 75.0,
#   'special_defense': 135.0,
#   'speed': 55.0},
#  263: {'name': 'Raikou',
#   'type': 'Electric',
#   'hp': 90.0,
#   'attack': 85.0,
#   'defense': 75.0,
#   'special_attack': 115.0,
#   'special_defense': 100.0,
#   'speed': 115.0},
#  264: {'name': 'Entei',
#   'type': 'Fire',
#   'hp': 115.0,
#   'attack': 115.0,
#   'defense': 85.0,
#   'special_attack': 90.0,
#   'special_defense': 75.0,
#   'speed': 100.0},
#  265: {'name': 'Suicune',
#   'type': 'Water',
#   'hp': 100.0,
#   'attack': 75.0,
#   'defense': 115.0,
#   'special_attack': 90.0,
#   'special_defense': 115.0,
#   'speed': 85.0},
#  266: {'name': 'Larvitar',
#   'type': 'RockGround',
#   'hp': 50.0,
#   'attack': 64.0,
#   'defense': 50.0,
#   'special_attack': 45.0,
#   'special_defense': 50.0,
#   'speed': 41.0},
#  267: {'name': 'Pupitar',
#   'type': 'RockGround',
#   'hp': 70.0,
#   'attack': 84.0,
#   'defense': 70.0,
#   'special_attack': 65.0,
#   'special_defense': 70.0,
#   'speed': 51.0},
#  268: {'name': 'Tyranitar',
#   'type': 'RockDark',
#   'hp': 100.0,
#   'attack': 134.0,
#   'defense': 110.0,
#   'special_attack': 95.0,
#   'special_defense': 100.0,
#   'speed': 61.0},
#  269: {'name': 'TyranitarMega Tyranitar',
#   'type': 'RockDark',
#   'hp': 100.0,
#   'attack': 164.0,
#   'defense': 150.0,
#   'special_attack': 95.0,
#   'special_defense': 120.0,
#   'speed': 71.0},
#  270: {'name': 'Lugia',
#   'type': 'PsychicFlying',
#   'hp': 106.0,
#   'attack': 90.0,
#   'defense': 130.0,
#   'special_attack': 90.0,
#   'special_defense': 154.0,
#   'speed': 110.0},
#  271: {'name': 'Ho-oh',
#   'type': 'FireFlying',
#   'hp': 106.0,
#   'attack': 130.0,
#   'defense': 90.0,
#   'special_attack': 110.0,
#   'special_defense': 154.0,
#   'speed': 90.0},
#  272: {'name': 'Celebi',
#   'type': 'PsychicGrass',
#   'hp': 100.0,
#   'attack': 100.0,
#   'defense': 100.0,
#   'special_attack': 100.0,
#   'special_defense': 100.0,
#   'speed': 100.0},
#  273: {'name': 'Treecko',
#   'type': 'Grass',
#   'hp': 40.0,
#   'attack': 45.0,
#   'defense': 35.0,
#   'special_attack': 65.0,
#   'special_defense': 55.0,
#   'speed': 70.0},
#  274: {'name': 'Grovyle',
#   'type': 'Grass',
#   'hp': 50.0,
#   'attack': 65.0,
#   'defense': 45.0,
#   'special_attack': 85.0,
#   'special_defense': 65.0,
#   'speed': 95.0},
#  275: {'name': 'Sceptile',
#   'type': 'Grass',
#   'hp': 70.0,
#   'attack': 85.0,
#   'defense': 65.0,
#   'special_attack': 105.0,
#   'special_defense': 85.0,
#   'speed': 120.0},
#  276: {'name': 'SceptileMega Sceptile',
#   'type': 'GrassDragon',
#   'hp': 70.0,
#   'attack': 110.0,
#   'defense': 75.0,
#   'special_attack': 145.0,
#   'special_defense': 85.0,
#   'speed': 145.0},
#  277: {'name': 'Torchic',
#   'type': 'Fire',
#   'hp': 45.0,
#   'attack': 60.0,
#   'defense': 40.0,
#   'special_attack': 70.0,
#   'special_defense': 50.0,
#   'speed': 45.0},
#  278: {'name': 'Combusken',
#   'type': 'FireFighting',
#   'hp': 60.0,
#   'attack': 85.0,
#   'defense': 60.0,
#   'special_attack': 85.0,
#   'special_defense': 60.0,
#   'speed': 55.0},
#  279: {'name': 'Blaziken',
#   'type': 'FireFighting',
#   'hp': 80.0,
#   'attack': 120.0,
#   'defense': 70.0,
#   'special_attack': 110.0,
#   'special_defense': 70.0,
# ...
#   'type': 'Poison',
#   'hp': 50.0,
#   'attack': 50.0,
#   'defense': 62.0,
#   'special_attack': 40.0,
#   'special_defense': 62.0,
#   'speed': 65.0},
#  631: {'name': 'Garbodor',
#   'type': 'Poison',
#   'hp': 80.0,
#   'attack': 95.0,
#   'defense': 82.0,
#   'special_attack': 60.0,
#   'special_defense': 82.0,
#   'speed': 75.0},
#  632: {'name': 'Zorua',
#   'type': 'Dark',
#   'hp': 40.0,
#   'attack': 65.0,
#   'defense': 40.0,
#   'special_attack': 80.0,
#   'special_defense': 40.0,
#   'speed': 65.0},
#  633: {'name': 'Zoroark',
#   'type': 'Dark',
#   'hp': 60.0,
#   'attack': 105.0,
#   'defense': 60.0,
#   'special_attack': 120.0,
#   'special_defense': 60.0,
#   'speed': 105.0},
#  634: {'name': 'Minccino',
#   'type': 'Normal',
#   'hp': 55.0,
#   'attack': 50.0,
#   'defense': 40.0,
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 75.0},
#  635: {'name': 'Cinccino',
#   'type': 'Normal',
#   'hp': 75.0,
#   'attack': 95.0,
#   'defense': 60.0,
#   'special_attack': 65.0,
#   'special_defense': 60.0,
#   'speed': 115.0},
#  636: {'name': 'Gothita',
#   'type': 'Psychic',
#   'hp': 45.0,
#   'attack': 30.0,
#   'defense': 50.0,
#   'special_attack': 55.0,
#   'special_defense': 65.0,
#   'speed': 45.0},
#  637: {'name': 'Gothorita',
#   'type': 'Psychic',
#   'hp': 60.0,
#   'attack': 45.0,
#   'defense': 70.0,
#   'special_attack': 75.0,
#   'special_defense': 85.0,
#   'speed': 55.0},
#  638: {'name': 'Gothitelle',
#   'type': 'Psychic',
#   'hp': 70.0,
#   'attack': 55.0,
#   'defense': 95.0,
#   'special_attack': 95.0,
#   'special_defense': 110.0,
#   'speed': 65.0},
#  639: {'name': 'Solosis',
#   'type': 'Psychic',
#   'hp': 45.0,
#   'attack': 30.0,
#   'defense': 40.0,
#   'special_attack': 105.0,
#   'special_defense': 50.0,
#   'speed': 20.0},
#  640: {'name': 'Duosion',
#   'type': 'Psychic',
#   'hp': 65.0,
#   'attack': 40.0,
#   'defense': 50.0,
#   'special_attack': 125.0,
#   'special_defense': 60.0,
#   'speed': 30.0},
#  641: {'name': 'Reuniclus',
#   'type': 'Psychic',
#   'hp': 110.0,
#   'attack': 65.0,
#   'defense': 75.0,
#   'special_attack': 125.0,
#   'special_defense': 85.0,
#   'speed': 30.0},
#  642: {'name': 'Ducklett',
#   'type': 'WaterFlying',
#   'hp': 62.0,
#   'attack': 44.0,
#   'defense': 50.0,
#   'special_attack': 44.0,
#   'special_defense': 50.0,
#   'speed': 55.0},
#  643: {'name': 'Swanna',
#   'type': 'WaterFlying',
#   'hp': 75.0,
#   'attack': 87.0,
#   'defense': 63.0,
#   'special_attack': 87.0,
#   'special_defense': 63.0,
#   'speed': 98.0},
#  644: {'name': 'Vanillite',
#   'type': 'Ice',
#   'hp': 36.0,
#   'attack': 50.0,
#   'defense': 50.0,
#   'special_attack': 65.0,
#   'special_defense': 60.0,
#   'speed': 44.0},
#  645: {'name': 'Vanillish',
#   'type': 'Ice',
#   'hp': 51.0,
#   'attack': 65.0,
#   'defense': 65.0,
#   'special_attack': 80.0,
#   'special_defense': 75.0,
#   'speed': 59.0},
#  646: {'name': 'Vanilluxe',
#   'type': 'Ice',
#   'hp': 71.0,
#   'attack': 95.0,
#   'defense': 85.0,
#   'special_attack': 110.0,
#   'special_defense': 95.0,
#   'speed': 79.0},
#  647: {'name': 'Deerling',
#   'type': 'NormalGrass',
#   'hp': 60.0,
#   'attack': 60.0,
#   'defense': 50.0,
#   'special_attack': 40.0,
#   'special_defense': 50.0,
#   'speed': 75.0},
#  648: {'name': 'Sawsbuck',
#   'type': 'NormalGrass',
#   'hp': 80.0,
#   'attack': 100.0,
#   'defense': 70.0,
#   'special_attack': 60.0,
#   'special_defense': 70.0,
#   'speed': 95.0},
#  649: {'name': 'Emolga',
#   'type': 'ElectricFlying',
#   'hp': 55.0,
#   'attack': 75.0,
#   'defense': 60.0,
#   'special_attack': 75.0,
#   'special_defense': 60.0,
#   'speed': 103.0},
#  650: {'name': 'Karrablast',
#   'type': 'Bug',
#   'hp': 50.0,
#   'attack': 75.0,
#   'defense': 45.0,
#   'special_attack': 40.0,
#   'special_defense': 45.0,
#   'speed': 60.0},
#  651: {'name': 'Escavalier',
#   'type': 'BugSteel',
#   'hp': 70.0,
#   'attack': 135.0,
#   'defense': 105.0,
#   'special_attack': 60.0,
#   'special_defense': 105.0,
#   'speed': 20.0},
#  652: {'name': 'Foongus',
#   'type': 'GrassPoison',
#   'hp': 69.0,
#   'attack': 55.0,
#   'defense': 45.0,
#   'special_attack': 55.0,
#   'special_defense': 55.0,
#   'speed': 15.0},
#  653: {'name': 'Amoonguss',
#   'type': 'GrassPoison',
#   'hp': 114.0,
#   'attack': 85.0,
#   'defense': 70.0,
#   'special_attack': 85.0,
#   'special_defense': 80.0,
#   'speed': 30.0},
#  654: {'name': 'Frillish',
#   'type': 'WaterGhost',
#   'hp': 55.0,
#   'attack': 40.0,
#   'defense': 50.0,
#   'special_attack': 65.0,
#   'special_defense': 85.0,
#   'speed': 40.0},
#  655: {'name': 'Jellicent',
#   'type': 'WaterGhost',
#   'hp': 100.0,
#   'attack': 60.0,
#   'defense': 70.0,
#   'special_attack': 85.0,
#   'special_defense': 105.0,
#   'speed': 60.0},
#  656: {'name': 'Alomomola',
#   'type': 'Water',
#   'hp': 165.0,
#   'attack': 75.0,
#   'defense': 80.0,
#   'special_attack': 40.0,
#   'special_defense': 45.0,
#   'speed': 65.0},
#  657: {'name': 'Joltik',
#   'type': 'BugElectric',
#   'hp': 50.0,
#   'attack': 47.0,
#   'defense': 50.0,
#   'special_attack': 57.0,
#   'special_defense': 50.0,
#   'speed': 65.0},
#  658: {'name': 'Galvantula',
#   'type': 'BugElectric',
#   'hp': 70.0,
#   'attack': 77.0,
#   'defense': 60.0,
#   'special_attack': 97.0,
#   'special_defense': 60.0,
#   'speed': 108.0},
#  659: {'name': 'Ferroseed',
#   'type': 'GrassSteel',
#   'hp': 44.0,
#   'attack': 50.0,
#   'defense': 91.0,
#   'special_attack': 24.0,
#   'special_defense': 86.0,
#   'speed': 10.0},
#  660: {'name': 'Ferrothorn',
#   'type': 'GrassSteel',
#   'hp': 74.0,
#   'attack': 94.0,
#   'defense': 131.0,
#   'special_attack': 54.0,
#   'special_defense': 116.0,
#   'speed': 20.0},
#  661: {'name': 'Klink',
#   'type': 'Steel',
#   'hp': 40.0,
#   'attack': 55.0,
#   'defense': 70.0,
#   'special_attack': 45.0,
#   'special_defense': 60.0,
#   'speed': 30.0},
#  662: {'name': 'Klang',
#   'type': 'Steel',
#   'hp': 60.0,
#   'attack': 80.0,
#   'defense': 95.0,
#   'special_attack': 70.0,
#   'special_defense': 85.0,
#   'speed': 50.0},
#  663: {'name': 'Klinklang',
#   'type': 'Steel',
#   'hp': 60.0,
#   'attack': 100.0,
#   'defense': 115.0,
#   'special_attack': 70.0,
#   'special_defense': 85.0,
#   'speed': 90.0},
#  664: {'name': 'Tynamo',
#   'type': 'Electric',
#   'hp': 35.0,
#   'attack': 55.0,
#   'defense': 40.0,
#   'special_attack': 45.0,
#   'special_defense': 40.0,
#   'speed': 60.0},
#  665: {'name': 'Eelektrik',
#   'type': 'Electric',
#   'hp': 65.0,
#   'attack': 85.0,
#   'defense': 70.0,
#   'special_attack': 75.0,
#   'special_defense': 70.0,
#   'speed': 40.0},
#  666: {'name': 'Eelektross',
#   'type': 'Electric',
#   'hp': 85.0,
#   'attack': 115.0,
#   'defense': 80.0,
#   'special_attack': 105.0,
#   'special_defense': 80.0,
#   'speed': 50.0},
#  667: {'name': 'Elgyem',
#   'type': 'Psychic',
#   'hp': 55.0,
#   'attack': 55.0,
#   'defense': 55.0,
#   'special_attack': 85.0,
#   'special_defense': 55.0,
#   'speed': 30.0},
#  668: {'name': 'Beheeyem',
#   'type': 'Psychic',
#   'hp': 75.0,
#   'attack': 75.0,
#   'defense': 75.0,
#   'special_attack': 125.0,
#   'special_defense': 95.0,
#   'speed': 40.0},
#  669: {'name': 'Litwick',
#   'type': 'GhostFire',
#   'hp': 50.0,
#   'attack': 30.0,
#   'defense': 55.0,
#   'special_attack': 65.0,
#   'special_defense': 55.0,
#   'speed': 20.0},
#  670: {'name': 'Lampent',
#   'type': 'GhostFire',
#   'hp': 60.0,
#   'attack': 40.0,
#   'defense': 60.0,
#   'special_attack': 95.0,
#   'special_defense': 60.0,
#   'speed': 55.0},
#  671: {'name': 'Chandelure',
#   'type': 'GhostFire',
#   'hp': 60.0,
#   'attack': 55.0,
#   'defense': 90.0,
#   'special_attack': 145.0,
#   'special_defense': 90.0,
#   'speed': 80.0},
#  672: {'name': 'Axew',
#   'type': 'Dragon',
#   'hp': 46.0,
#   'attack': 87.0,
#   'defense': 60.0,
#   'special_attack': 30.0,
#   'special_defense': 40.0,
#   'speed': 57.0},
#  673: {'name': 'Fraxure',
#   'type': 'Dragon',
#   'hp': 66.0,
#   'attack': 117.0,
#   'defense': 70.0,
#   'special_attack': 40.0,
#   'special_defense': 50.0,
#   'speed': 67.0},
#  674: {'name': 'Haxorus',
#   'type': 'Dragon',
#   'hp': 76.0,
#   'attack': 147.0,
#   'defense': 90.0,
#   'special_attack': 60.0,
#   'special_defense': 70.0,
#   'speed': 97.0},
#  675: {'name': 'Cubchoo',
#   'type': 'Ice',
#   'hp': 55.0,
#   'attack': 70.0,
#   'defense': 40.0,
#   'special_attack': 60.0,
#   'special_defense': 40.0,
#   'speed': 40.0},
#  676: {'name': 'Beartic',
#   'type': 'Ice',
#   'hp': 95.0,
#   'attack': 110.0,
#   'defense': 80.0,
#   'special_attack': 70.0,
#   'special_defense': 80.0,
#   'speed': 50.0},
#  677: {'name': 'Cryogonal',
#   'type': 'Ice',
#   'hp': 70.0,
#   'attack': 50.0,
#   'defense': 30.0,
#   'special_attack': 95.0,
#   'special_defense': 135.0,
#   'speed': 105.0},
#  678: {'name': 'Shelmet',
#   'type': 'Bug',
#   'hp': 50.0,
#   'attack': 40.0,
#   'defense': 85.0,
#   'special_attack': 40.0,
#   'special_defense': 65.0,
#   'speed': 25.0},
#  679: {'name': 'Accelgor',
#   'type': 'Bug',
#   'hp': 80.0,
#   'attack': 70.0,
#   'defense': 40.0,
#   'special_attack': 100.0,
#   'special_defense': 60.0,
#   'speed': 145.0},
#  680: {'name': 'Stunfisk',
#   'type': 'GroundElectric',
#   'hp': 109.0,
#   'attack': 66.0,
#   'defense': 84.0,
#   'special_attack': 81.0,
#   'special_defense': 99.0,
#   'speed': 32.0},
#  681: {'name': 'Mienfoo',
#   'type': 'Fighting',
#   'hp': 45.0,
#   'attack': 85.0,
#   'defense': 50.0,
#   'special_attack': 55.0,
#   'special_defense': 50.0,
#   'speed': 65.0},
#  682: {'name': 'Mienshao',
#   'type': 'Fighting',
#   'hp': 65.0,
#   'attack': 125.0,
#   'defense': 60.0,
#   'special_attack': 95.0,
#   'special_defense': 60.0,
#   'speed': 105.0},
#  683: {'name': 'Druddigon',
#   'type': 'Dragon',
#   'hp': 77.0,
#   'attack': 120.0,
#   'defense': 90.0,
#   'special_attack': 60.0,
#   'special_defense': 90.0,
#   'speed': 48.0},
#  684: {'name': 'Golett',
#   'type': 'GroundGhost',
#   'hp': 59.0,
#   'attack': 74.0,
#   'defense': 50.0,
#   'special_attack': 35.0,
#   'special_defense': 50.0,
#   'speed': 35.0},
#  685: {'name': 'Golurk',
#   'type': 'GroundGhost',
#   'hp': 89.0,
#   'attack': 124.0,
#   'defense': 80.0,
#   'special_attack': 55.0,
#   'special_defense': 80.0,
#   'speed': 55.0},
#  686: {'name': 'Pawniard',
#   'type': 'DarkSteel',
#   'hp': 45.0,
#   'attack': 85.0,
#   'defense': 70.0,
#   'special_attack': 40.0,
#   'special_defense': 40.0,
#   'speed': 60.0},
#  687: {'name': 'Bisharp',
#   'type': 'DarkSteel',
#   'hp': 65.0,
#   'attack': 125.0,
#   'defense': 100.0,
#   'special_attack': 60.0,
#   'special_defense': 70.0,
#   'speed': 70.0},
#  688: {'name': 'Bouffalant',
#   'type': 'Normal',
#   'hp': 95.0,
#   'attack': 110.0,
#   'defense': 95.0,
#   'special_attack': 40.0,
#   'special_defense': 95.0,
#   'speed': 55.0},
#  689: {'name': 'Rufflet',
#   'type': 'NormalFlying',
#   'hp': 70.0,
#   'attack': 83.0,
#   'defense': 50.0,
#   'special_attack': 37.0,
#   'special_defense': 50.0,
#   'speed': 60.0},
#  690: {'name': 'Braviary',
#   'type': 'NormalFlying',
#   'hp': 100.0,
#   'attack': 123.0,
#   'defense': 75.0,
#   'special_attack': 57.0,
#   'special_defense': 75.0,
#   'speed': 80.0},
#  691: {'name': 'Vullaby',
#   'type': 'DarkFlying',
#   'hp': 70.0,
#   'attack': 55.0,
#   'defense': 75.0,
#   'special_attack': 45.0,
#   'special_defense': 65.0,
#   'speed': 60.0},
#  692: {'name': 'Mandibuzz',
#   'type': 'DarkFlying',
#   'hp': 110.0,
#   'attack': 65.0,
#   'defense': 105.0,
#   'special_attack': 55.0,
#   'special_defense': 95.0,
#   'speed': 80.0},
#  693: {'name': 'Heatmor',
#   'type': 'Fire',
#   'hp': 85.0,
#   'attack': 97.0,
#   'defense': 66.0,
#   'special_attack': 105.0,
#   'special_defense': 66.0,
#   'speed': 65.0},
#  694: {'name': 'Durant',
#   'type': 'BugSteel',
#   'hp': 58.0,
#   'attack': 109.0,
#   'defense': 112.0,
#   'special_attack': 48.0,
#   'special_defense': 48.0,
#   'speed': 109.0},
#  695: {'name': 'Deino',
#   'type': 'DarkDragon',
#   'hp': 52.0,
#   'attack': 65.0,
#   'defense': 50.0,
#   'special_attack': 45.0,
#   'special_defense': 50.0,
#   'speed': 38.0},
#  696: {'name': 'Zweilous',
#   'type': 'DarkDragon',
#   'hp': 72.0,
#   'attack': 85.0,
#   'defense': 70.0,
#   'special_attack': 65.0,
#   'special_defense': 70.0,
#   'speed': 58.0},
#  697: {'name': 'Hydreigon',
#   'type': 'DarkDragon',
#   'hp': 92.0,
#   'attack': 105.0,
#   'defense': 90.0,
#   'special_attack': 125.0,
#   'special_defense': 90.0,
#   'speed': 98.0},
#  698: {'name': 'Larvesta',
#   'type': 'BugFire',
#   'hp': 55.0,
#   'attack': 85.0,
#   'defense': 55.0,
#   'special_attack': 50.0,
#   'special_defense': 55.0,
#   'speed': 60.0},
#  699: {'name': 'Volcarona',
#   'type': 'BugFire',
#   'hp': 85.0,
#   'attack': 60.0,
#   'defense': 65.0,
#   'special_attack': 135.0,
#   'special_defense': 105.0,
#   'speed': 100.0},
#  700: {'name': 'Cobalion',
#   'type': 'SteelFighting',
#   'hp': 91.0,
#   'attack': 90.0,
#   'defense': 129.0,
#   'special_attack': 90.0,
#   'special_defense': 72.0,
#   'speed': 108.0},
#  701: {'name': 'Terrakion',
#   'type': 'RockFighting',
#   'hp': 91.0,
#   'attack': 129.0,
#   'defense': 90.0,
#   'special_attack': 72.0,
#   'special_defense': 90.0,
#   'speed': 108.0},
#  702: {'name': 'Virizion',
#   'type': 'GrassFighting',
#   'hp': 91.0,
#   'attack': 90.0,
#   'defense': 72.0,
#   'special_attack': 90.0,
#   'special_defense': 129.0,
#   'speed': 108.0},
#  703: {'name': 'TornadusIncarnate Forme',
#   'type': 'Flying',
#   'hp': 79.0,
#   'attack': 115.0,
#   'defense': 70.0,
#   'special_attack': 125.0,
#   'special_defense': 80.0,
#   'speed': 111.0},
#  704: {'name': 'TornadusTherian Forme',
#   'type': 'Flying',
#   'hp': 79.0,
#   'attack': 100.0,
#   'defense': 80.0,
#   'special_attack': 110.0,
#   'special_defense': 90.0,
#   'speed': 121.0},
#  705: {'name': 'ThundurusIncarnate Forme',
#   'type': 'ElectricFlying',
#   'hp': 79.0,
#   'attack': 115.0,
#   'defense': 70.0,
#   'special_attack': 125.0,
#   'special_defense': 80.0,
#   'speed': 111.0},
#  706: {'name': 'ThundurusTherian Forme',
#   'type': 'ElectricFlying',
#   'hp': 79.0,
#   'attack': 105.0,
#   'defense': 70.0,
#   'special_attack': 145.0,
#   'special_defense': 80.0,
#   'speed': 101.0},
#  707: {'name': 'Reshiram',
#   'type': 'DragonFire',
#   'hp': 100.0,
#   'attack': 120.0,
#   'defense': 100.0,
#   'special_attack': 150.0,
#   'special_defense': 120.0,
#   'speed': 90.0},
#  708: {'name': 'Zekrom',
#   'type': 'DragonElectric',
#   'hp': 100.0,
#   'attack': 150.0,
#   'defense': 120.0,
#   'special_attack': 120.0,
#   'special_defense': 100.0,
#   'speed': 90.0},
#  709: {'name': 'LandorusIncarnate Forme',
#   'type': 'GroundFlying',
#   'hp': 89.0,
#   'attack': 125.0,
#   'defense': 90.0,
#   'special_attack': 115.0,
#   'special_defense': 80.0,
#   'speed': 101.0},
#  710: {'name': 'LandorusTherian Forme',
#   'type': 'GroundFlying',
#   'hp': 89.0,
#   'attack': 145.0,
#   'defense': 90.0,
#   'special_attack': 105.0,
#   'special_defense': 80.0,
#   'speed': 91.0},
#  711: {'name': 'Kyurem',
#   'type': 'DragonIce',
#   'hp': 125.0,
#   'attack': 130.0,
#   'defense': 90.0,
#   'special_attack': 130.0,
#   'special_defense': 90.0,
#   'speed': 95.0},
#  712: {'name': 'KyuremBlack Kyurem',
#   'type': 'DragonIce',
#   'hp': 125.0,
#   'attack': 170.0,
#   'defense': 100.0,
#   'special_attack': 120.0,
#   'special_defense': 90.0,
#   'speed': 95.0},
#  713: {'name': 'KyuremWhite Kyurem',
#   'type': 'DragonIce',
#   'hp': 125.0,
#   'attack': 120.0,
#   'defense': 90.0,
#   'special_attack': 170.0,
#   'special_defense': 100.0,
#   'speed': 95.0},
#  714: {'name': 'KeldeoOrdinary Forme',
#   'type': 'WaterFighting',
#   'hp': 91.0,
#   'attack': 72.0,
#   'defense': 90.0,
#   'special_attack': 129.0,
#   'special_defense': 90.0,
#   'speed': 108.0},
#  715: {'name': 'KeldeoResolute Forme',
#   'type': 'WaterFighting',
#   'hp': 91.0,
#   'attack': 72.0,
#   'defense': 90.0,
#   'special_attack': 129.0,
#   'special_defense': 90.0,
#   'speed': 108.0},
#  716: {'name': 'MeloettaAria Forme',
#   'type': 'NormalPsychic',
#   'hp': 100.0,
#   'attack': 77.0,
#   'defense': 77.0,
#   'special_attack': 128.0,
#   'special_defense': 128.0,
#   'speed': 90.0},
#  717: {'name': 'MeloettaPirouette Forme',
#   'type': 'NormalFighting',
#   'hp': 100.0,
#   'attack': 128.0,
#   'defense': 90.0,
#   'special_attack': 77.0,
#   'special_defense': 77.0,
#   'speed': 128.0},
#  718: {'name': 'Genesect',
#   'type': 'BugSteel',
#   'hp': 71.0,
#   'attack': 120.0,
#   'defense': 95.0,
#   'special_attack': 120.0,
#   'special_defense': 95.0,
#   'speed': 99.0},
#  719: {'name': 'Chespin',
#   'type': 'Grass',
#   'hp': 56.0,
#   'attack': 61.0,
#   'defense': 65.0,
#   'special_attack': 48.0,
#   'special_defense': 45.0,
#   'speed': 38.0},
#  720: {'name': 'Quilladin',
#   'type': 'Grass',
#   'hp': 61.0,
#   'attack': 78.0,
#   'defense': 95.0,
#   'special_attack': 56.0,
#   'special_defense': 58.0,
#   'speed': 57.0},
#  721: {'name': 'Chesnaught',
#   'type': 'GrassFighting',
#   'hp': 88.0,
#   'attack': 107.0,
#   'defense': 122.0,
#   'special_attack': 74.0,
#   'special_defense': 75.0,
#   'speed': 64.0}}

# %% [markdown]
# <img src="http://i.imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Write a function to generate a "filtered" pokedex
# ---
# Your function should:
# 1. Take the parsed pokedex information you created above as an argument.
# 1. Take a dictionary as a parameter with keys matching the features of the Pokedex, filtering by exact match for string type values, and/or filter continuous variables specified by a value that is greater than or equal to the value of the corresponding dictionary key parameter.
# 1. Return multiple elements from the Pokedex
#
# Example:
#
# ```python
#
# # Only filter based on parameters passed
# filter_options = {
#     'Attack':   25,
#     'Defense':  30,
#     'Type':     'Electric'
# }
#
# # Return records with attack >= 25, defense >= 30, and type == "Electric"
# # Also anticipate that other paramters can also be passed such as "SpecialAttack", "Speed", etc.
# filtered_pokedex(pokedex_data, filter=filter_options)
#
# # Example output:
# # [{'Attack': 30.0,
# #  'Defense': 50.0,
# #  'HP': 40.0,
# #  'Name': 'Voltorb',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  {'Attack': 30.0,
# #  'Defense': 33.0,
# #  'HP': 32.0,
# #  'Name': 'Pikachu',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  ... etc
# #  ]
#
# ```

# %%
# function to return pokemon with attributes specifed in filter_options

filter_options = {
    'Attack': 25,
    'defense': 30.0,
    'type': 'electric'}

def filtered_pokedex(pokedex,filter):

    filtered_pokedex_list = []
    
    for i in pokemon_id:
        add_pokemon=True
        for p,v in list(enumerate(filter.keys())):
            x=filter[v]
            y=pokedex[i][v.lower()]
            if isinstance(x,str):
                if x.lower()!=y.lower():
                    add_pokemon=False
            else:
                if y<x:
                    add_pokemon=False
        if add_pokemon:
            filtered_pokedex_list.append(pokedex[i])
                           
    return filtered_pokedex_list

filtered_pokedex(pokedex,filter=filter_options)
# Out:
# [{'name': 'Pikachu',
#   'type': 'Electric',
#   'hp': 35.0,
#   'attack': 55.0,
#   'defense': 40.0,
#   'special_attack': 50.0,
#   'special_defense': 50.0,
#   'speed': 90.0},
#  {'name': 'Raichu',
#   'type': 'Electric',
#   'hp': 60.0,
#   'attack': 90.0,
#   'defense': 55.0,
#   'special_attack': 90.0,
#   'special_defense': 80.0,
#   'speed': 110.0},
#  {'name': 'Voltorb',
#   'type': 'Electric',
#   'hp': 40.0,
#   'attack': 30.0,
#   'defense': 50.0,
#   'special_attack': 55.0,
#   'special_defense': 55.0,
#   'speed': 100.0},
#  {'name': 'Electrode',
#   'type': 'Electric',
#   'hp': 60.0,
#   'attack': 50.0,
#   'defense': 70.0,
#   'special_attack': 80.0,
#   'special_defense': 80.0,
#   'speed': 140.0},
#  {'name': 'Electabuzz',
#   'type': 'Electric',
#   'hp': 65.0,
#   'attack': 83.0,
#   'defense': 57.0,
#   'special_attack': 95.0,
#   'special_defense': 85.0,
#   'speed': 105.0},
#  {'name': 'Jolteon',
#   'type': 'Electric',
#   'hp': 65.0,
#   'attack': 65.0,
#   'defense': 60.0,
#   'special_attack': 110.0,
#   'special_defense': 95.0,
#   'speed': 130.0},
#  {'name': 'Mareep',
#   'type': 'Electric',
#   'hp': 55.0,
#   'attack': 40.0,
#   'defense': 40.0,
#   'special_attack': 65.0,
#   'special_defense': 45.0,
#   'speed': 35.0},
#  {'name': 'Flaaffy',
#   'type': 'Electric',
#   'hp': 70.0,
#   'attack': 55.0,
#   'defense': 55.0,
#   'special_attack': 80.0,
#   'special_defense': 60.0,
#   'speed': 45.0},
#  {'name': 'Ampharos',
#   'type': 'Electric',
#   'hp': 90.0,
#   'attack': 75.0,
#   'defense': 85.0,
#   'special_attack': 115.0,
#   'special_defense': 90.0,
#   'speed': 55.0},
#  {'name': 'Elekid',
#   'type': 'Electric',
#   'hp': 45.0,
#   'attack': 63.0,
#   'defense': 37.0,
#   'special_attack': 65.0,
#   'special_defense': 55.0,
#   'speed': 95.0},
#  {'name': 'Raikou',
#   'type': 'Electric',
#   'hp': 90.0,
#   'attack': 85.0,
#   'defense': 75.0,
#   'special_attack': 115.0,
#   'special_defense': 100.0,
#   'speed': 115.0},
#  {'name': 'Electrike',
#   'type': 'Electric',
#   'hp': 40.0,
#   'attack': 45.0,
#   'defense': 40.0,
#   'special_attack': 65.0,
#   'special_defense': 40.0,
#   'speed': 65.0},
#  {'name': 'Manectric',
#   'type': 'Electric',
#   'hp': 70.0,
#   'attack': 75.0,
#   'defense': 60.0,
#   'special_attack': 105.0,
#   'special_defense': 60.0,
#   'speed': 105.0},
#  {'name': 'ManectricMega Manectric',
#   'type': 'Electric',
#   'hp': 70.0,
#   'attack': 75.0,
#   'defense': 80.0,
#   'special_attack': 135.0,
#   'special_defense': 80.0,
#   'speed': 135.0},
#  {'name': 'Plusle',
#   'type': 'Electric',
#   'hp': 60.0,
#   'attack': 50.0,
#   'defense': 40.0,
#   'special_attack': 85.0,
#   'special_defense': 75.0,
#   'speed': 95.0},
#  {'name': 'Minun',
#   'type': 'Electric',
#   'hp': 60.0,
#   'attack': 40.0,
#   'defense': 50.0,
#   'special_attack': 75.0,
#   'special_defense': 85.0,
#   'speed': 95.0},
#  {'name': 'Shinx',
#   'type': 'Electric',
#   'hp': 45.0,
#   'attack': 65.0,
#   'defense': 34.0,
#   'special_attack': 40.0,
#   'special_defense': 34.0,
#   'speed': 45.0},
#  {'name': 'Luxio',
#   'type': 'Electric',
#   'hp': 60.0,
#   'attack': 85.0,
#   'defense': 49.0,
#   'special_attack': 60.0,
#   'special_defense': 49.0,
#   'speed': 60.0},
#  {'name': 'Luxray',
#   'type': 'Electric',
#   'hp': 80.0,
#   'attack': 120.0,
#   'defense': 79.0,
#   'special_attack': 95.0,
#   'special_defense': 79.0,
#   'speed': 70.0},
#  {'name': 'Pachirisu',
#   'type': 'Electric',
#   'hp': 60.0,
#   'attack': 45.0,
#   'defense': 70.0,
#   'special_attack': 45.0,
#   'special_defense': 90.0,
#   'speed': 95.0},
#  {'name': 'Electivire',
#   'type': 'Electric',
#   'hp': 75.0,
#   'attack': 123.0,
#   'defense': 67.0,
#   'special_attack': 95.0,
#   'special_defense': 85.0,
#   'speed': 95.0},
#  {'name': 'Blitzle',
#   'type': 'Electric',
#   'hp': 45.0,
#   'attack': 60.0,
#   'defense': 32.0,
#   'special_attack': 50.0,
#   'special_defense': 32.0,
#   'speed': 76.0},
#  {'name': 'Zebstrika',
#   'type': 'Electric',
#   'hp': 75.0,
#   'attack': 100.0,
#   'defense': 63.0,
#   'special_attack': 80.0,
#   'special_defense': 63.0,
#   'speed': 116.0},
#  {'name': 'Tynamo',
#   'type': 'Electric',
#   'hp': 35.0,
#   'attack': 55.0,
#   'defense': 40.0,
#   'special_attack': 45.0,
#   'special_defense': 40.0,
#   'speed': 60.0},
#  {'name': 'Eelektrik',
#   'type': 'Electric',
#   'hp': 65.0,
#   'attack': 85.0,
#   'defense': 70.0,
#   'special_attack': 75.0,
#   'special_defense': 70.0,
#   'speed': 40.0},
#  {'name': 'Eelektross',
#   'type': 'Electric',
#   'hp': 85.0,
#   'attack': 115.0,
#   'defense': 80.0,
#   'special_attack': 105.0,
#   'special_defense': 80.0,
#   'speed': 50.0}]

# %% [markdown]
# ## 11. Descriptive statistics on the prototype pokedex
#
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 11.1
#
# What is the population mean and standard deviation of the "Total" attribute for all characters in the Pokedex?

# %%
import numpy as np

# %%
total = [data_numeric[i][3] for i in pokemon_id]

std = np.std(total)

print('The mean is:',np.mean(total))
print('The standard deviation is:',std)
# Out:
# The mean is: 434.575
# The standard deviation is: 120.58924858792348

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 11.2
#
# The game is no fun if the characters are wildly unbalanced! Are any characters "overpowered", which we'll define as having a "Total" more than three standard deviations from the population mean?

# %%
# Dictionary of pokemons and their total power found in data_numeric[k][3]

total_per_pok = {pokedex[k]['name']:data_numeric[k][3] for k in pokemon_id}
total_per_pok
# Out:
# {'Bulbasaur': 318.0,
#  'Ivysaur': 405.0,
#  'Venusaur': 525.0,
#  'VenusaurMega Venusaur': 625.0,
#  'Charmander': 309.0,
#  'Charmeleon': 405.0,
#  'Charizard': 534.0,
#  'CharizardMega Charizard X': 634.0,
#  'CharizardMega Charizard Y': 634.0,
#  'Squirtle': 314.0,
#  'Wartortle': 405.0,
#  'Blastoise': 530.0,
#  'BlastoiseMega Blastoise': 630.0,
#  'Caterpie': 195.0,
#  'Metapod': 205.0,
#  'Butterfree': 395.0,
#  'Weedle': 195.0,
#  'Kakuna': 205.0,
#  'Beedrill': 395.0,
#  'BeedrillMega Beedrill': 495.0,
#  'Pidgey': 251.0,
#  'Pidgeotto': 349.0,
#  'Pidgeot': 479.0,
#  'PidgeotMega Pidgeot': 579.0,
#  'Rattata': 253.0,
#  'Raticate': 413.0,
#  'Spearow': 262.0,
#  'Fearow': 442.0,
#  'Ekans': 288.0,
#  'Arbok': 438.0,
#  'Pikachu': 320.0,
#  'Raichu': 485.0,
#  'Sandshrew': 300.0,
#  'Sandslash': 450.0,
#  'NidoranF': 275.0,
#  'Nidorina': 365.0,
#  'Nidoqueen': 505.0,
#  'NidoranM': 273.0,
#  'Nidorino': 365.0,
#  'Nidoking': 505.0,
#  'Clefairy': 323.0,
#  'Clefable': 483.0,
#  'Vulpix': 299.0,
#  'Ninetales': 505.0,
#  'Jigglypuff': 270.0,
#  'Wigglytuff': 435.0,
#  'Zubat': 245.0,
#  'Golbat': 455.0,
#  'Oddish': 320.0,
#  'Gloom': 395.0,
#  'Vileplume': 490.0,
#  'Paras': 285.0,
#  'Parasect': 405.0,
#  'Venonat': 305.0,
#  'Venomoth': 450.0,
#  'Diglett': 265.0,
#  'Dugtrio': 405.0,
#  'Meowth': 290.0,
#  'Persian': 440.0,
#  'Psyduck': 320.0,
#  'Golduck': 500.0,
#  'Mankey': 305.0,
#  'Primeape': 455.0,
#  'Growlithe': 350.0,
#  'Arcanine': 555.0,
#  'Poliwag': 300.0,
#  'Poliwhirl': 385.0,
#  'Poliwrath': 510.0,
#  'Abra': 310.0,
#  'Kadabra': 400.0,
#  'Alakazam': 500.0,
#  'AlakazamMega Alakazam': 590.0,
#  'Machop': 305.0,
#  'Machoke': 405.0,
#  'Machamp': 505.0,
#  'Bellsprout': 300.0,
#  'Weepinbell': 390.0,
#  'Victreebel': 490.0,
#  'Tentacool': 335.0,
#  'Tentacruel': 515.0,
#  'Geodude': 300.0,
#  'Graveler': 390.0,
#  'Golem': 495.0,
#  'Ponyta': 410.0,
#  'Rapidash': 500.0,
#  'Slowpoke': 315.0,
#  'Slowbro': 490.0,
#  'SlowbroMega Slowbro': 590.0,
#  'Magnemite': 325.0,
#  'Magneton': 465.0,
#  "Farfetch'd": 352.0,
#  'Doduo': 310.0,
#  'Dodrio': 460.0,
#  'Seel': 325.0,
#  'Dewgong': 475.0,
#  'Grimer': 325.0,
#  'Muk': 500.0,
#  'Shellder': 305.0,
#  'Cloyster': 525.0,
#  'Gastly': 310.0,
#  'Haunter': 405.0,
#  'Gengar': 500.0,
#  'GengarMega Gengar': 600.0,
#  'Onix': 385.0,
#  'Drowzee': 328.0,
#  'Hypno': 483.0,
#  'Krabby': 325.0,
#  'Kingler': 475.0,
#  'Voltorb': 330.0,
#  'Electrode': 480.0,
#  'Exeggcute': 325.0,
#  'Exeggutor': 520.0,
#  'Cubone': 320.0,
#  'Marowak': 425.0,
#  'Hitmonlee': 455.0,
#  'Hitmonchan': 455.0,
#  'Lickitung': 385.0,
#  'Koffing': 340.0,
#  'Weezing': 490.0,
#  'Rhyhorn': 345.0,
#  'Rhydon': 485.0,
#  'Chansey': 450.0,
#  'Tangela': 435.0,
#  'Kangaskhan': 490.0,
#  'KangaskhanMega Kangaskhan': 590.0,
#  'Horsea': 295.0,
#  'Seadra': 440.0,
#  'Goldeen': 320.0,
#  'Seaking': 450.0,
#  'Staryu': 340.0,
#  'Starmie': 520.0,
#  'Mr. Mime': 460.0,
#  'Scyther': 500.0,
#  'Jynx': 455.0,
#  'Electabuzz': 490.0,
#  'Magmar': 495.0,
#  'Pinsir': 500.0,
#  'PinsirMega Pinsir': 600.0,
#  'Tauros': 490.0,
#  'Magikarp': 200.0,
#  'Gyarados': 540.0,
#  'GyaradosMega Gyarados': 640.0,
#  'Lapras': 535.0,
#  'Ditto': 288.0,
#  'Eevee': 325.0,
#  'Vaporeon': 525.0,
#  'Jolteon': 525.0,
#  'Flareon': 525.0,
#  'Porygon': 395.0,
#  'Omanyte': 355.0,
#  'Omastar': 495.0,
#  'Kabuto': 355.0,
#  'Kabutops': 495.0,
#  'Aerodactyl': 515.0,
#  'AerodactylMega Aerodactyl': 615.0,
#  'Snorlax': 540.0,
#  'Articuno': 580.0,
#  'Zapdos': 580.0,
#  'Moltres': 580.0,
#  'Dratini': 300.0,
#  'Dragonair': 420.0,
#  'Dragonite': 600.0,
#  'Mewtwo': 680.0,
#  'MewtwoMega Mewtwo X': 800.0,
#  'MewtwoMega Mewtwo Y': 780.0,
#  'Mew': 600.0,
#  'Chikorita': 318.0,
#  'Bayleef': 405.0,
#  'Meganium': 525.0,
#  'Cyndaquil': 309.0,
#  'Quilava': 405.0,
#  'Typhlosion': 534.0,
#  'Totodile': 314.0,
#  'Croconaw': 405.0,
#  'Feraligatr': 530.0,
#  'Sentret': 215.0,
#  'Furret': 415.0,
#  'Hoothoot': 262.0,
#  'Noctowl': 442.0,
#  'Ledyba': 265.0,
#  'Ledian': 390.0,
#  'Spinarak': 250.0,
#  'Ariados': 390.0,
#  'Crobat': 535.0,
#  'Chinchou': 330.0,
#  'Lanturn': 460.0,
#  'Pichu': 205.0,
#  'Cleffa': 218.0,
#  'Igglybuff': 210.0,
#  'Togepi': 245.0,
#  'Togetic': 405.0,
#  'Natu': 320.0,
#  'Xatu': 470.0,
#  'Mareep': 280.0,
#  'Flaaffy': 365.0,
#  'Ampharos': 510.0,
#  'AmpharosMega Ampharos': 610.0,
#  'Bellossom': 490.0,
#  'Marill': 250.0,
#  'Azumarill': 420.0,
#  'Sudowoodo': 410.0,
#  'Politoed': 500.0,
#  'Hoppip': 250.0,
#  'Skiploom': 340.0,
#  'Jumpluff': 460.0,
#  'Aipom': 360.0,
#  'Sunkern': 180.0,
#  'Sunflora': 425.0,
#  'Yanma': 390.0,
#  'Wooper': 210.0,
#  'Quagsire': 430.0,
#  'Espeon': 525.0,
#  'Umbreon': 525.0,
#  'Murkrow': 405.0,
#  'Slowking': 490.0,
#  'Misdreavus': 435.0,
#  'Unown': 336.0,
#  'Wobbuffet': 405.0,
#  'Girafarig': 455.0,
#  'Pineco': 290.0,
#  'Forretress': 465.0,
#  'Dunsparce': 415.0,
#  'Gligar': 430.0,
#  'Steelix': 510.0,
#  'SteelixMega Steelix': 610.0,
#  'Snubbull': 300.0,
#  'Granbull': 450.0,
#  'Qwilfish': 430.0,
#  'Scizor': 500.0,
#  'ScizorMega Scizor': 600.0,
#  'Shuckle': 505.0,
#  'Heracross': 500.0,
#  'HeracrossMega Heracross': 600.0,
#  'Sneasel': 430.0,
#  'Teddiursa': 330.0,
#  'Ursaring': 500.0,
#  'Slugma': 250.0,
#  'Magcargo': 410.0,
#  'Swinub': 250.0,
#  'Piloswine': 450.0,
#  'Corsola': 380.0,
#  'Remoraid': 300.0,
#  'Octillery': 480.0,
#  'Delibird': 330.0,
#  'Mantine': 465.0,
#  'Skarmory': 465.0,
#  'Houndour': 330.0,
#  'Houndoom': 500.0,
#  'HoundoomMega Houndoom': 600.0,
#  'Kingdra': 540.0,
#  'Phanpy': 330.0,
#  'Donphan': 500.0,
#  'Porygon2': 515.0,
#  'Stantler': 465.0,
#  'Smeargle': 250.0,
#  'Tyrogue': 210.0,
#  'Hitmontop': 455.0,
#  'Smoochum': 305.0,
#  'Elekid': 360.0,
#  'Magby': 365.0,
#  'Miltank': 490.0,
#  'Blissey': 540.0,
#  'Raikou': 580.0,
#  'Entei': 580.0,
#  'Suicune': 580.0,
#  'Larvitar': 300.0,
#  'Pupitar': 410.0,
#  'Tyranitar': 600.0,
#  'TyranitarMega Tyranitar': 700.0,
#  'Lugia': 680.0,
#  'Ho-oh': 680.0,
#  'Celebi': 600.0,
#  'Treecko': 310.0,
#  'Grovyle': 405.0,
#  'Sceptile': 530.0,
#  'SceptileMega Sceptile': 630.0,
#  'Torchic': 310.0,
#  'Combusken': 405.0,
#  'Blaziken': 530.0,
#  'BlazikenMega Blaziken': 630.0,
#  'Mudkip': 310.0,
#  'Marshtomp': 405.0,
#  'Swampert': 535.0,
#  'SwampertMega Swampert': 635.0,
#  'Poochyena': 220.0,
#  'Mightyena': 420.0,
#  'Zigzagoon': 240.0,
#  'Linoone': 420.0,
#  'Wurmple': 195.0,
#  'Silcoon': 205.0,
#  'Beautifly': 395.0,
#  'Cascoon': 205.0,
#  'Dustox': 385.0,
#  'Lotad': 220.0,
#  'Lombre': 340.0,
#  'Ludicolo': 480.0,
#  'Seedot': 220.0,
#  'Nuzleaf': 340.0,
#  'Shiftry': 480.0,
#  'Taillow': 270.0,
#  'Swellow': 430.0,
#  'Wingull': 270.0,
#  'Pelipper': 430.0,
#  'Ralts': 198.0,
#  'Kirlia': 278.0,
#  'Gardevoir': 518.0,
#  'GardevoirMega Gardevoir': 618.0,
#  'Surskit': 269.0,
#  'Masquerain': 414.0,
#  'Shroomish': 295.0,
#  'Breloom': 460.0,
#  'Slakoth': 280.0,
#  'Vigoroth': 440.0,
#  'Slaking': 670.0,
#  'Nincada': 266.0,
#  'Ninjask': 456.0,
#  'Shedinja': 236.0,
#  'Whismur': 240.0,
#  'Loudred': 360.0,
#  'Exploud': 490.0,
#  'Makuhita': 237.0,
#  'Hariyama': 474.0,
#  'Azurill': 190.0,
#  'Nosepass': 375.0,
#  'Skitty': 260.0,
#  'Delcatty': 380.0,
#  'Sableye': 380.0,
#  'SableyeMega Sableye': 480.0,
#  'Mawile': 380.0,
#  'MawileMega Mawile': 480.0,
#  'Aron': 330.0,
#  'Lairon': 430.0,
#  'Aggron': 530.0,
#  'AggronMega Aggron': 630.0,
#  'Meditite': 280.0,
#  'Medicham': 410.0,
#  'MedichamMega Medicham': 510.0,
#  'Electrike': 295.0,
#  'Manectric': 475.0,
#  'ManectricMega Manectric': 575.0,
#  'Plusle': 405.0,
#  'Minun': 405.0,
#  'Volbeat': 400.0,
#  'Illumise': 400.0,
#  'Roselia': 400.0,
#  'Gulpin': 302.0,
#  'Swalot': 467.0,
#  'Carvanha': 305.0,
#  'Sharpedo': 460.0,
#  'SharpedoMega Sharpedo': 560.0,
#  'Wailmer': 400.0,
#  'Wailord': 500.0,
#  'Numel': 305.0,
#  'Camerupt': 460.0,
#  'CameruptMega Camerupt': 560.0,
#  'Torkoal': 470.0,
#  'Spoink': 330.0,
#  'Grumpig': 470.0,
#  'Spinda': 360.0,
#  'Trapinch': 290.0,
#  'Vibrava': 340.0,
#  'Flygon': 520.0,
#  'Cacnea': 335.0,
#  'Cacturne': 475.0,
#  'Swablu': 310.0,
#  'Altaria': 490.0,
#  'AltariaMega Altaria': 590.0,
#  'Zangoose': 458.0,
#  'Seviper': 458.0,
#  'Lunatone': 440.0,
#  'Solrock': 440.0,
#  'Barboach': 288.0,
#  'Whiscash': 468.0,
#  'Corphish': 308.0,
#  'Crawdaunt': 468.0,
#  'Baltoy': 300.0,
#  'Claydol': 500.0,
#  'Lileep': 355.0,
#  'Cradily': 495.0,
#  'Anorith': 355.0,
#  'Armaldo': 495.0,
#  'Feebas': 200.0,
#  'Milotic': 540.0,
#  'Castform': 420.0,
#  'Kecleon': 440.0,
#  'Shuppet': 295.0,
#  'Banette': 455.0,
#  'BanetteMega Banette': 555.0,
#  'Duskull': 295.0,
#  'Dusclops': 455.0,
#  'Tropius': 460.0,
#  'Chimecho': 425.0,
#  'Absol': 465.0,
#  'AbsolMega Absol': 565.0,
#  'Wynaut': 260.0,
#  'Snorunt': 300.0,
#  'Glalie': 480.0,
#  'GlalieMega Glalie': 580.0,
#  'Spheal': 290.0,
#  'Sealeo': 410.0,
#  'Walrein': 530.0,
#  'Clamperl': 345.0,
#  'Huntail': 485.0,
#  'Gorebyss': 485.0,
#  'Relicanth': 485.0,
#  'Luvdisc': 330.0,
#  'Bagon': 300.0,
#  'Shelgon': 420.0,
#  'Salamence': 600.0,
#  'SalamenceMega Salamence': 700.0,
#  'Beldum': 300.0,
#  'Metang': 420.0,
#  'Metagross': 600.0,
#  'MetagrossMega Metagross': 700.0,
#  'Regirock': 580.0,
#  'Regice': 580.0,
#  'Registeel': 580.0,
#  'Latias': 600.0,
#  'LatiasMega Latias': 700.0,
#  'Latios': 600.0,
#  'LatiosMega Latios': 700.0,
#  'Kyogre': 670.0,
#  'KyogrePrimal Kyogre': 770.0,
#  'Groudon': 670.0,
#  'GroudonPrimal Groudon': 770.0,
#  'Rayquaza': 680.0,
#  'RayquazaMega Rayquaza': 780.0,
#  'Jirachi': 600.0,
#  'DeoxysNormal Forme': 600.0,
#  'DeoxysAttack Forme': 600.0,
#  'DeoxysDefense Forme': 600.0,
#  'DeoxysSpeed Forme': 600.0,
#  'Turtwig': 318.0,
#  'Grotle': 405.0,
#  'Torterra': 525.0,
#  'Chimchar': 309.0,
#  'Monferno': 405.0,
#  'Infernape': 534.0,
#  'Piplup': 314.0,
#  'Prinplup': 405.0,
#  'Empoleon': 530.0,
#  'Starly': 245.0,
#  'Staravia': 340.0,
#  'Staraptor': 485.0,
#  'Bidoof': 250.0,
#  'Bibarel': 410.0,
#  'Kricketot': 194.0,
#  'Kricketune': 384.0,
#  'Shinx': 263.0,
#  'Luxio': 363.0,
#  'Luxray': 523.0,
#  'Budew': 280.0,
#  'Roserade': 515.0,
#  'Cranidos': 350.0,
#  'Rampardos': 495.0,
#  'Shieldon': 350.0,
#  'Bastiodon': 495.0,
#  'Burmy': 224.0,
#  'WormadamPlant Cloak': 424.0,
#  'WormadamSandy Cloak': 424.0,
#  'WormadamTrash Cloak': 424.0,
#  'Mothim': 424.0,
#  'Combee': 244.0,
#  'Vespiquen': 474.0,
#  'Pachirisu': 405.0,
#  'Buizel': 330.0,
#  'Floatzel': 495.0,
#  'Cherubi': 275.0,
#  'Cherrim': 450.0,
#  'Shellos': 325.0,
#  'Gastrodon': 475.0,
#  'Ambipom': 482.0,
#  'Drifloon': 348.0,
#  'Drifblim': 498.0,
#  'Buneary': 350.0,
#  'Lopunny': 480.0,
#  'LopunnyMega Lopunny': 580.0,
#  'Mismagius': 495.0,
#  'Honchkrow': 505.0,
#  'Glameow': 310.0,
#  'Purugly': 452.0,
#  'Chingling': 285.0,
#  'Stunky': 329.0,
#  'Skuntank': 479.0,
#  'Bronzor': 300.0,
#  'Bronzong': 500.0,
#  'Bonsly': 290.0,
#  'Mime Jr.': 310.0,
#  'Happiny': 220.0,
#  'Chatot': 411.0,
#  'Spiritomb': 485.0,
#  'Gible': 300.0,
#  'Gabite': 410.0,
#  'Garchomp': 600.0,
#  'GarchompMega Garchomp': 700.0,
#  'Munchlax': 390.0,
#  'Riolu': 285.0,
#  'Lucario': 525.0,
#  'LucarioMega Lucario': 625.0,
#  'Hippopotas': 330.0,
#  'Hippowdon': 525.0,
#  'Skorupi': 330.0,
#  'Drapion': 500.0,
#  'Croagunk': 300.0,
#  'Toxicroak': 490.0,
#  'Carnivine': 454.0,
#  'Finneon': 330.0,
#  'Lumineon': 460.0,
#  'Mantyke': 345.0,
#  'Snover': 334.0,
#  'Abomasnow': 494.0,
#  'AbomasnowMega Abomasnow': 594.0,
#  'Weavile': 510.0,
#  'Magnezone': 535.0,
#  'Lickilicky': 515.0,
#  'Rhyperior': 535.0,
#  'Tangrowth': 535.0,
#  'Electivire': 540.0,
#  'Magmortar': 540.0,
#  'Togekiss': 545.0,
#  'Yanmega': 515.0,
#  'Leafeon': 525.0,
#  'Glaceon': 525.0,
#  'Gliscor': 510.0,
#  'Mamoswine': 530.0,
#  'Porygon-Z': 535.0,
#  'Gallade': 518.0,
#  'GalladeMega Gallade': 618.0,
#  'Probopass': 525.0,
#  'Dusknoir': 525.0,
#  'Froslass': 480.0,
#  'Rotom': 440.0,
#  'RotomHeat Rotom': 520.0,
#  'RotomWash Rotom': 520.0,
#  'RotomFrost Rotom': 520.0,
#  'RotomFan Rotom': 520.0,
#  'RotomMow Rotom': 520.0,
#  'Uxie': 580.0,
#  'Mesprit': 580.0,
#  'Azelf': 580.0,
#  'Dialga': 680.0,
#  'Palkia': 680.0,
#  'Heatran': 600.0,
#  'Regigigas': 670.0,
#  'GiratinaAltered Forme': 680.0,
#  'GiratinaOrigin Forme': 680.0,
#  'Cresselia': 600.0,
#  'Phione': 480.0,
#  'Manaphy': 600.0,
#  'Darkrai': 600.0,
#  'ShayminLand Forme': 600.0,
#  'ShayminSky Forme': 600.0,
#  'Arceus': 720.0,
#  'Victini': 600.0,
#  'Snivy': 308.0,
#  'Servine': 413.0,
#  'Serperior': 528.0,
#  'Tepig': 308.0,
#  'Pignite': 418.0,
#  'Emboar': 528.0,
#  'Oshawott': 308.0,
#  'Dewott': 413.0,
#  'Samurott': 528.0,
#  'Patrat': 255.0,
#  'Watchog': 420.0,
#  'Lillipup': 275.0,
#  'Herdier': 370.0,
#  'Stoutland': 500.0,
#  'Purrloin': 281.0,
#  'Liepard': 446.0,
#  'Pansage': 316.0,
#  'Simisage': 498.0,
#  'Pansear': 316.0,
#  'Simisear': 498.0,
#  'Panpour': 316.0,
#  'Simipour': 498.0,
#  'Munna': 292.0,
#  'Musharna': 487.0,
#  'Pidove': 264.0,
#  'Tranquill': 358.0,
#  'Unfezant': 488.0,
#  'Blitzle': 295.0,
#  'Zebstrika': 497.0,
#  'Roggenrola': 280.0,
#  'Boldore': 390.0,
#  'Gigalith': 515.0,
#  'Woobat': 313.0,
#  'Swoobat': 425.0,
#  'Drilbur': 328.0,
#  'Excadrill': 508.0,
#  'Audino': 445.0,
#  'AudinoMega Audino': 545.0,
#  'Timburr': 305.0,
#  'Gurdurr': 405.0,
#  'Conkeldurr': 505.0,
#  'Tympole': 294.0,
#  'Palpitoad': 384.0,
#  'Seismitoad': 509.0,
#  'Throh': 465.0,
#  'Sawk': 465.0,
#  'Sewaddle': 310.0,
#  'Swadloon': 380.0,
#  'Leavanny': 500.0,
#  'Venipede': 260.0,
#  'Whirlipede': 360.0,
#  'Scolipede': 485.0,
#  'Cottonee': 280.0,
#  'Whimsicott': 480.0,
#  'Petilil': 280.0,
#  'Lilligant': 480.0,
#  'Basculin': 460.0,
#  'Sandile': 292.0,
#  'Krokorok': 351.0,
#  'Krookodile': 519.0,
#  'Darumaka': 315.0,
#  'DarmanitanStandard Mode': 480.0,
#  'DarmanitanZen Mode': 540.0,
#  'Maractus': 461.0,
#  'Dwebble': 325.0,
#  'Crustle': 475.0,
#  'Scraggy': 348.0,
#  'Scrafty': 488.0,
#  'Sigilyph': 490.0,
#  'Yamask': 303.0,
#  'Cofagrigus': 483.0,
#  'Tirtouga': 355.0,
#  'Carracosta': 495.0,
#  'Archen': 401.0,
#  'Archeops': 567.0,
#  'Trubbish': 329.0,
#  'Garbodor': 474.0,
#  'Zorua': 330.0,
#  'Zoroark': 510.0,
#  'Minccino': 300.0,
#  'Cinccino': 470.0,
#  'Gothita': 290.0,
#  'Gothorita': 390.0,
#  'Gothitelle': 490.0,
#  'Solosis': 290.0,
#  'Duosion': 370.0,
#  'Reuniclus': 490.0,
#  'Ducklett': 305.0,
#  'Swanna': 473.0,
#  'Vanillite': 305.0,
#  'Vanillish': 395.0,
#  'Vanilluxe': 535.0,
#  'Deerling': 335.0,
#  'Sawsbuck': 475.0,
#  'Emolga': 428.0,
#  'Karrablast': 315.0,
#  'Escavalier': 495.0,
#  'Foongus': 294.0,
#  'Amoonguss': 464.0,
#  'Frillish': 335.0,
#  'Jellicent': 480.0,
#  'Alomomola': 470.0,
#  'Joltik': 319.0,
#  'Galvantula': 472.0,
#  'Ferroseed': 305.0,
#  'Ferrothorn': 489.0,
#  'Klink': 300.0,
#  'Klang': 440.0,
#  'Klinklang': 520.0,
#  'Tynamo': 275.0,
#  'Eelektrik': 405.0,
#  'Eelektross': 515.0,
#  'Elgyem': 335.0,
#  'Beheeyem': 485.0,
#  'Litwick': 275.0,
#  'Lampent': 370.0,
#  'Chandelure': 520.0,
#  'Axew': 320.0,
#  'Fraxure': 410.0,
#  'Haxorus': 540.0,
#  'Cubchoo': 305.0,
#  'Beartic': 485.0,
#  'Cryogonal': 485.0,
#  'Shelmet': 305.0,
#  'Accelgor': 495.0,
#  'Stunfisk': 471.0,
#  'Mienfoo': 350.0,
#  'Mienshao': 510.0,
#  'Druddigon': 485.0,
#  'Golett': 303.0,
#  'Golurk': 483.0,
#  'Pawniard': 340.0,
#  'Bisharp': 490.0,
#  'Bouffalant': 490.0,
#  'Rufflet': 350.0,
#  'Braviary': 510.0,
#  'Vullaby': 370.0,
#  'Mandibuzz': 510.0,
#  'Heatmor': 484.0,
#  'Durant': 484.0,
#  'Deino': 300.0,
#  'Zweilous': 420.0,
#  'Hydreigon': 600.0,
#  'Larvesta': 360.0,
#  'Volcarona': 550.0,
#  'Cobalion': 580.0,
#  'Terrakion': 580.0,
#  'Virizion': 580.0,
#  'TornadusIncarnate Forme': 580.0,
#  'TornadusTherian Forme': 580.0,
#  'ThundurusIncarnate Forme': 580.0,
#  'ThundurusTherian Forme': 580.0,
#  'Reshiram': 680.0,
#  'Zekrom': 680.0,
#  'LandorusIncarnate Forme': 600.0,
#  'LandorusTherian Forme': 600.0,
#  'Kyurem': 660.0,
#  'KyuremBlack Kyurem': 700.0,
#  'KyuremWhite Kyurem': 700.0,
#  'KeldeoOrdinary Forme': 580.0,
#  'KeldeoResolute Forme': 580.0,
#  'MeloettaAria Forme': 600.0,
#  'MeloettaPirouette Forme': 600.0,
#  'Genesect': 600.0,
#  'Chespin': 313.0,
#  'Quilladin': 405.0,
#  'Chesnaught': 530.0}

# %%
print("Total power limit",3*std)
print('All the below pokemons are overpowered:')

# return list of all overpowered pokemons defined by total power[value] > 3* the standard deviation

[{key:value} for (key,value) in total_per_pok.items() if value > 3*std]
# Out:
# Total power limit 361.76774576377045
# All the below pokemons are overpowered:
# [{'Ivysaur': 405.0},
#  {'Venusaur': 525.0},
#  {'VenusaurMega Venusaur': 625.0},
#  {'Charmeleon': 405.0},
#  {'Charizard': 534.0},
#  {'CharizardMega Charizard X': 634.0},
#  {'CharizardMega Charizard Y': 634.0},
#  {'Wartortle': 405.0},
#  {'Blastoise': 530.0},
#  {'BlastoiseMega Blastoise': 630.0},
#  {'Butterfree': 395.0},
#  {'Beedrill': 395.0},
#  {'BeedrillMega Beedrill': 495.0},
#  {'Pidgeot': 479.0},
#  {'PidgeotMega Pidgeot': 579.0},
#  {'Raticate': 413.0},
#  {'Fearow': 442.0},
#  {'Arbok': 438.0},
#  {'Raichu': 485.0},
#  {'Sandslash': 450.0},
#  {'Nidorina': 365.0},
#  {'Nidoqueen': 505.0},
#  {'Nidorino': 365.0},
#  {'Nidoking': 505.0},
#  {'Clefable': 483.0},
#  {'Ninetales': 505.0},
#  {'Wigglytuff': 435.0},
#  {'Golbat': 455.0},
#  {'Gloom': 395.0},
#  {'Vileplume': 490.0},
#  {'Parasect': 405.0},
#  {'Venomoth': 450.0},
#  {'Dugtrio': 405.0},
#  {'Persian': 440.0},
#  {'Golduck': 500.0},
#  {'Primeape': 455.0},
#  {'Arcanine': 555.0},
#  {'Poliwhirl': 385.0},
#  {'Poliwrath': 510.0},
#  {'Kadabra': 400.0},
#  {'Alakazam': 500.0},
#  {'AlakazamMega Alakazam': 590.0},
#  {'Machoke': 405.0},
#  {'Machamp': 505.0},
#  {'Weepinbell': 390.0},
#  {'Victreebel': 490.0},
#  {'Tentacruel': 515.0},
#  {'Graveler': 390.0},
#  {'Golem': 495.0},
#  {'Ponyta': 410.0},
#  {'Rapidash': 500.0},
#  {'Slowbro': 490.0},
#  {'SlowbroMega Slowbro': 590.0},
#  {'Magneton': 465.0},
#  {'Dodrio': 460.0},
#  {'Dewgong': 475.0},
#  {'Muk': 500.0},
#  {'Cloyster': 525.0},
#  {'Haunter': 405.0},
#  {'Gengar': 500.0},
#  {'GengarMega Gengar': 600.0},
#  {'Onix': 385.0},
#  {'Hypno': 483.0},
#  {'Kingler': 475.0},
#  {'Electrode': 480.0},
#  {'Exeggutor': 520.0},
#  {'Marowak': 425.0},
#  {'Hitmonlee': 455.0},
#  {'Hitmonchan': 455.0},
#  {'Lickitung': 385.0},
#  {'Weezing': 490.0},
#  {'Rhydon': 485.0},
#  {'Chansey': 450.0},
#  {'Tangela': 435.0},
#  {'Kangaskhan': 490.0},
#  {'KangaskhanMega Kangaskhan': 590.0},
#  {'Seadra': 440.0},
#  {'Seaking': 450.0},
#  {'Starmie': 520.0},
#  {'Mr. Mime': 460.0},
#  {'Scyther': 500.0},
#  {'Jynx': 455.0},
#  {'Electabuzz': 490.0},
#  {'Magmar': 495.0},
#  {'Pinsir': 500.0},
#  {'PinsirMega Pinsir': 600.0},
#  {'Tauros': 490.0},
#  {'Gyarados': 540.0},
#  {'GyaradosMega Gyarados': 640.0},
#  {'Lapras': 535.0},
#  {'Vaporeon': 525.0},
#  {'Jolteon': 525.0},
#  {'Flareon': 525.0},
#  {'Porygon': 395.0},
#  {'Omastar': 495.0},
#  {'Kabutops': 495.0},
#  {'Aerodactyl': 515.0},
#  {'AerodactylMega Aerodactyl': 615.0},
#  {'Snorlax': 540.0},
#  {'Articuno': 580.0},
#  {'Zapdos': 580.0},
#  {'Moltres': 580.0},
#  {'Dragonair': 420.0},
#  {'Dragonite': 600.0},
#  {'Mewtwo': 680.0},
#  {'MewtwoMega Mewtwo X': 800.0},
#  {'MewtwoMega Mewtwo Y': 780.0},
#  {'Mew': 600.0},
#  {'Bayleef': 405.0},
#  {'Meganium': 525.0},
#  {'Quilava': 405.0},
#  {'Typhlosion': 534.0},
#  {'Croconaw': 405.0},
#  {'Feraligatr': 530.0},
#  {'Furret': 415.0},
#  {'Noctowl': 442.0},
#  {'Ledian': 390.0},
#  {'Ariados': 390.0},
#  {'Crobat': 535.0},
#  {'Lanturn': 460.0},
#  {'Togetic': 405.0},
#  {'Xatu': 470.0},
#  {'Flaaffy': 365.0},
#  {'Ampharos': 510.0},
#  {'AmpharosMega Ampharos': 610.0},
#  {'Bellossom': 490.0},
#  {'Azumarill': 420.0},
#  {'Sudowoodo': 410.0},
#  {'Politoed': 500.0},
#  {'Jumpluff': 460.0},
#  {'Sunflora': 425.0},
#  {'Yanma': 390.0},
#  {'Quagsire': 430.0},
#  {'Espeon': 525.0},
#  {'Umbreon': 525.0},
#  {'Murkrow': 405.0},
#  {'Slowking': 490.0},
#  {'Misdreavus': 435.0},
#  {'Wobbuffet': 405.0},
#  {'Girafarig': 455.0},
#  {'Forretress': 465.0},
#  {'Dunsparce': 415.0},
#  {'Gligar': 430.0},
#  {'Steelix': 510.0},
#  {'SteelixMega Steelix': 610.0},
#  {'Granbull': 450.0},
#  {'Qwilfish': 430.0},
#  {'Scizor': 500.0},
#  {'ScizorMega Scizor': 600.0},
#  {'Shuckle': 505.0},
#  {'Heracross': 500.0},
#  {'HeracrossMega Heracross': 600.0},
#  {'Sneasel': 430.0},
#  {'Ursaring': 500.0},
#  {'Magcargo': 410.0},
#  {'Piloswine': 450.0},
#  {'Corsola': 380.0},
#  {'Octillery': 480.0},
#  {'Mantine': 465.0},
#  {'Skarmory': 465.0},
#  {'Houndoom': 500.0},
#  {'HoundoomMega Houndoom': 600.0},
#  {'Kingdra': 540.0},
#  {'Donphan': 500.0},
#  {'Porygon2': 515.0},
#  {'Stantler': 465.0},
#  {'Hitmontop': 455.0},
#  {'Magby': 365.0},
#  {'Miltank': 490.0},
#  {'Blissey': 540.0},
#  {'Raikou': 580.0},
#  {'Entei': 580.0},
#  {'Suicune': 580.0},
#  {'Pupitar': 410.0},
#  {'Tyranitar': 600.0},
#  {'TyranitarMega Tyranitar': 700.0},
#  {'Lugia': 680.0},
#  {'Ho-oh': 680.0},
#  {'Celebi': 600.0},
#  {'Grovyle': 405.0},
#  {'Sceptile': 530.0},
#  {'SceptileMega Sceptile': 630.0},
#  {'Combusken': 405.0},
#  {'Blaziken': 530.0},
#  {'BlazikenMega Blaziken': 630.0},
#  {'Marshtomp': 405.0},
#  {'Swampert': 535.0},
#  {'SwampertMega Swampert': 635.0},
#  {'Mightyena': 420.0},
#  {'Linoone': 420.0},
#  {'Beautifly': 395.0},
#  {'Dustox': 385.0},
#  {'Ludicolo': 480.0},
#  {'Shiftry': 480.0},
#  {'Swellow': 430.0},
#  {'Pelipper': 430.0},
#  {'Gardevoir': 518.0},
#  {'GardevoirMega Gardevoir': 618.0},
#  {'Masquerain': 414.0},
#  {'Breloom': 460.0},
#  {'Vigoroth': 440.0},
#  {'Slaking': 670.0},
#  {'Ninjask': 456.0},
#  {'Exploud': 490.0},
#  {'Hariyama': 474.0},
#  {'Nosepass': 375.0},
#  {'Delcatty': 380.0},
#  {'Sableye': 380.0},
#  {'SableyeMega Sableye': 480.0},
#  {'Mawile': 380.0},
#  {'MawileMega Mawile': 480.0},
#  {'Lairon': 430.0},
#  {'Aggron': 530.0},
#  {'AggronMega Aggron': 630.0},
#  {'Medicham': 410.0},
#  {'MedichamMega Medicham': 510.0},
#  {'Manectric': 475.0},
#  {'ManectricMega Manectric': 575.0},
#  {'Plusle': 405.0},
#  {'Minun': 405.0},
#  {'Volbeat': 400.0},
#  {'Illumise': 400.0},
#  {'Roselia': 400.0},
#  {'Swalot': 467.0},
#  {'Sharpedo': 460.0},
#  {'SharpedoMega Sharpedo': 560.0},
#  {'Wailmer': 400.0},
#  {'Wailord': 500.0},
#  {'Camerupt': 460.0},
#  {'CameruptMega Camerupt': 560.0},
#  {'Torkoal': 470.0},
#  {'Grumpig': 470.0},
#  {'Flygon': 520.0},
#  {'Cacturne': 475.0},
#  {'Altaria': 490.0},
#  {'AltariaMega Altaria': 590.0},
#  {'Zangoose': 458.0},
#  {'Seviper': 458.0},
#  {'Lunatone': 440.0},
#  {'Solrock': 440.0},
#  {'Whiscash': 468.0},
#  {'Crawdaunt': 468.0},
#  {'Claydol': 500.0},
#  {'Cradily': 495.0},
#  {'Armaldo': 495.0},
#  {'Milotic': 540.0},
#  {'Castform': 420.0},
#  {'Kecleon': 440.0},
#  {'Banette': 455.0},
#  {'BanetteMega Banette': 555.0},
#  {'Dusclops': 455.0},
#  {'Tropius': 460.0},
#  {'Chimecho': 425.0},
#  {'Absol': 465.0},
#  {'AbsolMega Absol': 565.0},
#  {'Glalie': 480.0},
#  {'GlalieMega Glalie': 580.0},
#  {'Sealeo': 410.0},
#  {'Walrein': 530.0},
#  {'Huntail': 485.0},
#  {'Gorebyss': 485.0},
#  {'Relicanth': 485.0},
#  {'Shelgon': 420.0},
#  {'Salamence': 600.0},
#  {'SalamenceMega Salamence': 700.0},
#  {'Metang': 420.0},
#  {'Metagross': 600.0},
#  {'MetagrossMega Metagross': 700.0},
#  {'Regirock': 580.0},
#  {'Regice': 580.0},
#  {'Registeel': 580.0},
#  {'Latias': 600.0},
#  {'LatiasMega Latias': 700.0},
#  {'Latios': 600.0},
#  {'LatiosMega Latios': 700.0},
#  {'Kyogre': 670.0},
#  {'KyogrePrimal Kyogre': 770.0},
#  {'Groudon': 670.0},
#  {'GroudonPrimal Groudon': 770.0},
#  {'Rayquaza': 680.0},
#  {'RayquazaMega Rayquaza': 780.0},
#  {'Jirachi': 600.0},
#  {'DeoxysNormal Forme': 600.0},
#  {'DeoxysAttack Forme': 600.0},
#  {'DeoxysDefense Forme': 600.0},
#  {'DeoxysSpeed Forme': 600.0},
#  {'Grotle': 405.0},
#  {'Torterra': 525.0},
#  {'Monferno': 405.0},
#  {'Infernape': 534.0},
#  {'Prinplup': 405.0},
#  {'Empoleon': 530.0},
#  {'Staraptor': 485.0},
#  {'Bibarel': 410.0},
#  {'Kricketune': 384.0},
#  {'Luxio': 363.0},
#  {'Luxray': 523.0},
#  {'Roserade': 515.0},
#  {'Rampardos': 495.0},
#  {'Bastiodon': 495.0},
#  {'WormadamPlant Cloak': 424.0},
#  {'WormadamSandy Cloak': 424.0},
#  {'WormadamTrash Cloak': 424.0},
#  {'Mothim': 424.0},
#  {'Vespiquen': 474.0},
#  {'Pachirisu': 405.0},
#  {'Floatzel': 495.0},
#  {'Cherrim': 450.0},
#  {'Gastrodon': 475.0},
#  {'Ambipom': 482.0},
#  {'Drifblim': 498.0},
#  {'Lopunny': 480.0},
#  {'LopunnyMega Lopunny': 580.0},
#  {'Mismagius': 495.0},
#  {'Honchkrow': 505.0},
#  {'Purugly': 452.0},
#  {'Skuntank': 479.0},
#  {'Bronzong': 500.0},
#  {'Chatot': 411.0},
#  {'Spiritomb': 485.0},
#  {'Gabite': 410.0},
#  {'Garchomp': 600.0},
#  {'GarchompMega Garchomp': 700.0},
#  {'Munchlax': 390.0},
#  {'Lucario': 525.0},
#  {'LucarioMega Lucario': 625.0},
#  {'Hippowdon': 525.0},
#  {'Drapion': 500.0},
#  {'Toxicroak': 490.0},
#  {'Carnivine': 454.0},
#  {'Lumineon': 460.0},
#  {'Abomasnow': 494.0},
#  {'AbomasnowMega Abomasnow': 594.0},
#  {'Weavile': 510.0},
#  {'Magnezone': 535.0},
#  {'Lickilicky': 515.0},
#  {'Rhyperior': 535.0},
#  {'Tangrowth': 535.0},
#  {'Electivire': 540.0},
#  {'Magmortar': 540.0},
#  {'Togekiss': 545.0},
#  {'Yanmega': 515.0},
#  {'Leafeon': 525.0},
#  {'Glaceon': 525.0},
#  {'Gliscor': 510.0},
#  {'Mamoswine': 530.0},
#  {'Porygon-Z': 535.0},
#  {'Gallade': 518.0},
#  {'GalladeMega Gallade': 618.0},
#  {'Probopass': 525.0},
#  {'Dusknoir': 525.0},
#  {'Froslass': 480.0},
#  {'Rotom': 440.0},
#  {'RotomHeat Rotom': 520.0},
#  {'RotomWash Rotom': 520.0},
#  {'RotomFrost Rotom': 520.0},
#  {'RotomFan Rotom': 520.0},
#  {'RotomMow Rotom': 520.0},
#  {'Uxie': 580.0},
#  {'Mesprit': 580.0},
#  {'Azelf': 580.0},
#  {'Dialga': 680.0},
#  {'Palkia': 680.0},
#  {'Heatran': 600.0},
#  {'Regigigas': 670.0},
#  {'GiratinaAltered Forme': 680.0},
#  {'GiratinaOrigin Forme': 680.0},
#  {'Cresselia': 600.0},
#  {'Phione': 480.0},
#  {'Manaphy': 600.0},
#  {'Darkrai': 600.0},
#  {'ShayminLand Forme': 600.0},
#  {'ShayminSky Forme': 600.0},
#  {'Arceus': 720.0},
#  {'Victini': 600.0},
#  {'Servine': 413.0},
#  {'Serperior': 528.0},
#  {'Pignite': 418.0},
#  {'Emboar': 528.0},
#  {'Dewott': 413.0},
#  {'Samurott': 528.0},
#  {'Watchog': 420.0},
#  {'Herdier': 370.0},
#  {'Stoutland': 500.0},
#  {'Liepard': 446.0},
#  {'Simisage': 498.0},
#  {'Simisear': 498.0},
#  {'Simipour': 498.0},
#  {'Musharna': 487.0},
#  {'Unfezant': 488.0},
#  {'Zebstrika': 497.0},
#  {'Boldore': 390.0},
#  {'Gigalith': 515.0},
#  {'Swoobat': 425.0},
#  {'Excadrill': 508.0},
#  {'Audino': 445.0},
#  {'AudinoMega Audino': 545.0},
#  {'Gurdurr': 405.0},
#  {'Conkeldurr': 505.0},
#  {'Palpitoad': 384.0},
#  {'Seismitoad': 509.0},
#  {'Throh': 465.0},
#  {'Sawk': 465.0},
#  {'Swadloon': 380.0},
#  {'Leavanny': 500.0},
#  {'Scolipede': 485.0},
#  {'Whimsicott': 480.0},
#  {'Lilligant': 480.0},
#  {'Basculin': 460.0},
#  {'Krookodile': 519.0},
#  {'DarmanitanStandard Mode': 480.0},
#  {'DarmanitanZen Mode': 540.0},
#  {'Maractus': 461.0},
#  {'Crustle': 475.0},
#  {'Scrafty': 488.0},
#  {'Sigilyph': 490.0},
#  {'Cofagrigus': 483.0},
#  {'Carracosta': 495.0},
#  {'Archen': 401.0},
#  {'Archeops': 567.0},
#  {'Garbodor': 474.0},
#  {'Zoroark': 510.0},
#  {'Cinccino': 470.0},
#  {'Gothorita': 390.0},
#  {'Gothitelle': 490.0},
#  {'Duosion': 370.0},
#  {'Reuniclus': 490.0},
#  {'Swanna': 473.0},
#  {'Vanillish': 395.0},
#  {'Vanilluxe': 535.0},
#  {'Sawsbuck': 475.0},
#  {'Emolga': 428.0},
#  {'Escavalier': 495.0},
#  {'Amoonguss': 464.0},
#  {'Jellicent': 480.0},
#  {'Alomomola': 470.0},
#  {'Galvantula': 472.0},
#  {'Ferrothorn': 489.0},
#  {'Klang': 440.0},
#  {'Klinklang': 520.0},
#  {'Eelektrik': 405.0},
#  {'Eelektross': 515.0},
#  {'Beheeyem': 485.0},
#  {'Lampent': 370.0},
#  {'Chandelure': 520.0},
#  {'Fraxure': 410.0},
#  {'Haxorus': 540.0},
#  {'Beartic': 485.0},
#  {'Cryogonal': 485.0},
#  {'Accelgor': 495.0},
#  {'Stunfisk': 471.0},
#  {'Mienshao': 510.0},
#  {'Druddigon': 485.0},
#  {'Golurk': 483.0},
#  {'Bisharp': 490.0},
#  {'Bouffalant': 490.0},
#  {'Braviary': 510.0},
#  {'Vullaby': 370.0},
#  {'Mandibuzz': 510.0},
#  {'Heatmor': 484.0},
#  {'Durant': 484.0},
#  {'Zweilous': 420.0},
#  {'Hydreigon': 600.0},
#  {'Volcarona': 550.0},
#  {'Cobalion': 580.0},
#  {'Terrakion': 580.0},
#  {'Virizion': 580.0},
#  {'TornadusIncarnate Forme': 580.0},
#  {'TornadusTherian Forme': 580.0},
#  {'ThundurusIncarnate Forme': 580.0},
#  {'ThundurusTherian Forme': 580.0},
#  {'Reshiram': 680.0},
#  {'Zekrom': 680.0},
#  {'LandorusIncarnate Forme': 600.0},
#  {'LandorusTherian Forme': 600.0},
#  {'Kyurem': 660.0},
#  {'KyuremBlack Kyurem': 700.0},
#  {'KyuremWhite Kyurem': 700.0},
#  {'KeldeoOrdinary Forme': 580.0},
#  {'KeldeoResolute Forme': 580.0},
#  {'MeloettaAria Forme': 600.0},
#  {'MeloettaPirouette Forme': 600.0},
#  {'Genesect': 600.0},
#  {'Quilladin': 405.0},
#  {'Chesnaught': 530.0}]

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 12. Calibrate the frequency of Pokemon
#
# The design team wants you to make the powerful Pokemon rare, and the weaklings more common. How would you set the probability $p_i$ of finding Pokemon *i* each time a player visits a gym?
#
# Write a function that takes in a Pokedex number and returns a value $p_i$ for that character.
#
# Hint: there are many ways you could do this. What do _you_ think makes sense? Start with simplifying assumptions: for example, you could assume that the probabilities of encountering any two Pokemon on one visit to a gym are independent of each other.
